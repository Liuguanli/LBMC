# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from mpl_toolkits.axisartist.axislines import SubplotZero
import matplotlib.patches as patches
import random
import math
import copy
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import PathPatch
from matplotlib.path import Path

plt.rc('font',family='Times New Roman',size=20)
from hilbertcurve.hilbertcurve import HilbertCurve

# plt.rc('lines', linewidth=3)

# labelsize=20
# fontsize=20
# legend_fontsize=20
# lw = 4
floder="SIGMOD2024"
is_save = False
is_save = True
bit_letters = ["A", "B", "C", "D", "E"]
window_color = "red"
point_color = "dimgray"
page_color = "darkviolet"
text_colot = "black"
curve_color="dimgrey"
section_color="red"
import warnings
warnings.filterwarnings('ignore')
from matplotlib.transforms import Affine2D
fontsize=36

plt.rcParams['hatch.linewidth'] = 2
# plt.rcParams['mathtext.default'] = 'DejaVu Sans'
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['mathtext.rm'] = 'serif'

# %%
class Point:
    def __init__(self, xs, value=0):
        self.xs = xs
        self.value = value
        self.dim = len(xs)
        
    def __str__(self):
        return "pos: " + " ".join(map(str,self.xs)) + " val: " + str(self.value) + "\n"
    
    def __repr__(self):
        return "pos: " + " ".join(map(str,self.xs)) + " val: " + str(self.value) + "\n"

# %%
class Window:
    def __init__(self, dimension_low, dimension_high):
        assert len(dimension_low) == len(dimension_high), "dimension_low and dimension_high should be same dimension"
        self.point_l = Point(dimension_low)
        self.point_h = Point(dimension_high)
        self.dimension_low = [math.ceil(_ - 0.5) for _ in dimension_low]
        self.dimension_high = [math.floor(_ - 0.5) for _ in dimension_high]
        self.dim = len(dimension_low)
        
    def cal_curve_len(self):
        pass
    
    def cal_query_sections_num(self):
        pass
    
    def __str__(self):
        return "pl: " + str(self.point_l) + " ph:" + str(self.point_h)

# %%
def generate_windows(grid_resolution=16, dimension=2, dimension_length=[0.1,0.1], window_num=1):
    windows = []
    dimension_length = [_ * grid_resolution for _ in dimension_length]
#     print(dimension_length)
    for i in range(window_num):
        dimension_low = []
        dimension_high = []
        for j in range(dimension):
            while True:
                res = random.random() * grid_resolution
                if (res >= 0 and res + dimension_length[j] <= grid_resolution):
                    dimension_low.append(res)
                    dimension_high.append(res + dimension_length[j])
#                     dimension_low.append(math.ceil(res))
#                     dimension_high.append(math.floor(res + dimension_length[j]))
                    break
        window = Window(dimension_low, dimension_high)
        windows.append(window)
    return windows
#     return windows

# %%
# a method to transfrom 'xyxyxyxy' to [[7,5,3,1],[6,4,2,0]] 
def get_z_value(x, bits_order=[[1,3,5,7],[0,2,4,6]]):
    res = 0
    x_len = len(x)
    bits = len(bits_order[0])
    for i in range(bits):
        for j in range(x_len):
            res+= int(x[j] % 2) * 1 << (bits_order[j][i])
            x[j] /= 2
    return res

# %%
def get_points(grid_size, bits_str):
    print(bits_str[::-1])
    bits=[[i for i, x in enumerate(bits_str) if x == 'X'],[i for i, x in enumerate(bits_str) if x == 'Y']]
    points = []
    for i in range(grid_size):
        for j in range(grid_size): 
            xs = [i, j]
            point = Point(xs, get_z_value(xs.copy(), bits))
            points.append(point)
    points.sort(key=lambda Point: Point.value, reverse=False)
    return points

# %%
def plot_z_curve_section_demo(grid_size, points, windows=None, query_section_range=None, title="", name=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax=plt.gca()
    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
#     x=[0,1,2,3,4,5,6,7]
#     my_xticks = ['   0','   1','   2','   3','   4','   5','   6','   7']
#     plt.xticks(x, my_xticks, ha='left')
#     ax.set_yticklabels(['0\n\n','1\n\n','2\n\n','3\n\n','4\n\n','5\n\n','6\n\n','7\n\n'])
    plt.xticks([])
    ax.set_yticklabels([])
    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize*1.5) 
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize*1.5) 
    ax.grid(True, linestyle='solid',linewidth=1)
#     plt.text(4.1, 5.9, '$Q_2$', fontsize=30, color=window_color)
#     plt.text(0.6, 3.4, '$Q_1$', fontsize=30, color=window_color)


#     plt.title("BMC " + title, fontsize=30)
    
    xs = []    
    ys = []
    qs_xs = []
    qs_ys = []
    for i in range(64):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
        if i >= query_section_range[0] and i <= query_section_range[1]:
            qs_xs.append(points[i].xs[0]+0.5)
            qs_ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    plt.plot(qs_xs, qs_ys, color='blue', linestyle='-.', linewidth=4)
    
    if title.startswith('X'):
        ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    else:
        ax.arrow(7.6, 7.5, 0.01, 0, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    for i in range(0, grid_size - 1, 1):
        plt.plot([i + 1, i + 1], [0,grid_size], color='lightgray', linestyle='-',linewidth = 1)
    for index, window in enumerate(windows):
        ax.add_patch(window)
    plt.text(2, 0.2, '$q_' + str(1) + '$', fontsize=50, color=window_color)
    plt.text(4.5, 5.4, '$q_' + str(2) + '$', fontsize=50, color=window_color)
    plt.text(4, 2.7, '$q_' + str(3) + '$', fontsize=50, color=window_color)
    plt.text(4.5, 1.3, '$q_' + str(4) + '$', fontsize=50, color=window_color)
    
    plt.xlabel("x", fontsize=60)
    plt.ylabel("y", fontsize=60)
    ax.xaxis.set_label_coords(.5, 0.01)
    ax.yaxis.set_label_coords(-.01, .5)
    
#     if is_save:
#         plt.savefig('../../../../应用/Overleaf/'+floder + name + '.eps',format='eps',bbox_inches = 'tight')
#         plt.savefig('../../../../应用/Overleaf/'+floder + name + '.pdf',format='pdf',bbox_inches = 'tight')
#         plt.savefig('../../../../应用/Overleaf/'+floder + name + '.png',format='png',bbox_inches = 'tight')
    plt.show()

# %%
grid_size = 8
w1 = patches.Rectangle((4, 6),3.9,1.95, linewidth=4, edgecolor=window_color, facecolor='none')
w2 = patches.Rectangle((0.05, 0.05),1.95,4, linewidth=4, edgecolor=window_color, facecolor='none')
w3 = patches.Rectangle((3.05, 0.05),4.9,0.95, linewidth=4, edgecolor=window_color, facecolor='none')
w4 = patches.Rectangle((3.05, 2.05),0.9,2.95, linewidth=4, edgecolor=window_color, facecolor='none')
windows=[w2, w1, w4, w3]
bits_str = 'YXYXYX'[::-1]
plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, [56, 63], bits_str[::-1], name="ZC_sele_YXYXYX")
# Out:
# YXYXYX

# %%
grid_size = 8
bits_str = 'XYXYXY'[::-1]
w1 = patches.Rectangle((4, 6),3.9,1.95, linewidth=4, edgecolor=window_color, facecolor='none')
w2 = patches.Rectangle((0.05, 0.05),1.95,4, linewidth=4, edgecolor=window_color, facecolor='none')
w3 = patches.Rectangle((3.05, 0.05),4.9,0.95, linewidth=4, edgecolor=window_color, facecolor='none')
w4 = patches.Rectangle((3.05, 2.05),0.9,2.95, linewidth=4, edgecolor=window_color, facecolor='none')
windows=[w2, w1, w4, w3]
plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, [0, 7], bits_str[::-1], name="ZC_sele_XYXYXY")
# Out:
# XYXYXY

# %%
grid_size = 8
bits_str = 'YYYXXX'[::-1]
w1 = patches.Rectangle((4, 6),3.9,1.95, linewidth=4, edgecolor=window_color, facecolor='none')
w2 = patches.Rectangle((0.05, 0.05),1.95,4, linewidth=4, edgecolor=window_color, facecolor='none')
w3 = patches.Rectangle((3.05, 0.05),4.9,0.95, linewidth=4, edgecolor=window_color, facecolor='none')
w4 = patches.Rectangle((3.05, 2.05),0.9,2.95, linewidth=4, edgecolor=window_color, facecolor='none')
windows=[w2, w1, w4, w3]
plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, [3, 7], bits_str[::-1], name="ZC_sele_YYYXXX")
# Out:
# YYYXXX

# %%
grid_size = 8
bits_str = 'XXXYYY'[::-1]
w1 = patches.Rectangle((4, 6),3.9,1.95, linewidth=4, edgecolor=window_color, facecolor='none')
w2 = patches.Rectangle((0.05, 0.05),1.95,4, linewidth=4, edgecolor=window_color, facecolor='none')
w3 = patches.Rectangle((3.05, 0.05),4.9,0.95, linewidth=4, edgecolor=window_color, facecolor='none')
w4 = patches.Rectangle((3.05, 2.05),0.9,2.95, linewidth=4, edgecolor=window_color, facecolor='none')
windows=[w2, w1, w4, w3]
plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, [26, 28], bits_str[::-1], name="ZC_sele_XXXYYY")
# Out:
# XXXYYY

# %%
def get_points(grid_size, bits_str):
    print(bits_str[::-1])
    bits=[[i for i, x in enumerate(bits_str) if x == 'X'],[i for i, x in enumerate(bits_str) if x == 'Y']]
    points = []
    for i in range(grid_size):
        for j in range(grid_size): 
            xs = [i, j]
            point = Point(xs, get_z_value(xs.copy(), bits))
            points.append(point)
    points.sort(key=lambda Point: Point.value, reverse=False)
    return points

# %%
def plot_zc(grid_size, points, colors, windows=[], title=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax=plt.gca()

    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
    x=[0,1,2,3]
#     my_xticks = ['  00','  01','  10','  11']
#     plt.xticks(x, my_xticks, ha='left')
#     ax.set_yticklabels(['00\n\n','01\n\n','10\n\n','11\n\n'])
    my_xticks = ['   0','   1','   2','   3']
    plt.xticks(x, my_xticks, ha='left')

#     ax.set_xticklabels(['      0','      1','      2','      3','      4','      5','      6','      7'])
#     ax.set_xticklabels(['0','1','2','3','4','      5','      6','      7'])
    ax.set_yticklabels(['0\n\n','1\n\n','2\n\n','3\n\n'])
    plt.xticks([])
    ax.set_yticklabels([])
#     ax.tick_params(axis='x', colors='red')   
    print(fontsize)
    plt.xlabel("x", fontsize=fontsize*2)
    plt.ylabel("y", fontsize=fontsize*2)
    ax.xaxis.set_label_coords(.5, -.01)
    ax.yaxis.set_label_coords(-.01, .5)

    if ax is None:
        ax = plt.gca()
#     ax.tick_params(axis='x', pad=30)
    
    canvas = ax.figure.canvas
    
    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(24)
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(24) 

    xs = []    
    ys = []
    for i in range(grid_size * grid_size):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
        
    for i in range(len(xs) - 1):
        is_in_window = False
        for j, window in enumerate(windows):
            if window.xy[0] > xs[i]:
                continue
            if xs[i] > window.xy[0] + window.get_width():
                continue
            if window.xy[1] > ys[i]:
                continue
            if ys[i] > window.xy[1] + window.get_height():
                continue
            is_in_window = True
            if window.xy[0] > xs[i + 1]:
                is_in_window = False
            if xs[i + 1] > window.xy[0] + window.get_width():
                is_in_window = False
            if window.xy[1] > ys[i + 1]:
                is_in_window = False
            if ys[i + 1] > window.xy[1] + window.get_height():
                is_in_window = False
            if j ==2 and not is_in_window:
                plt.scatter(xs[i], ys[i],color='blue',linewidths=1)
            break

        if is_in_window:
            plt.plot(xs[i:i + 2],
                     ys[i:i + 2],
                     color='blue',
                     linestyle='-',
                     linewidth=4)
        else:
            plt.plot(xs[i:i + 2],
                     ys[i:i + 2],
                     color='lightgray',
                     linestyle='-.',
                     linewidth=4)
    for i in range(0, grid_size - 1, 1):
        plt.plot([i + 1, i + 1], [0,grid_size], color='lightgray', linestyle='-',linewidth = 1)
#     plt.plot([2,2], [0,grid_size], color='lightgray', linestyle='-',linewidth = 1)
#     plt.plot([3,3], [0,grid_size], color='lightgray', linestyle='-',linewidth = 1)
    ax.grid(True, linestyle='solid',linewidth=1)
    
    for index, window in enumerate(windows):
        ax.add_patch(window)
    plt.text(2, 0.2, '$q_' + str(1) + '$', fontsize=60, color=window_color)
    plt.text(4.5, 1.3, '$q_' + str(3) + '$', fontsize=60, color=window_color)
    plt.text(4.5, 5.4, '$q_' + str(2) + '$', fontsize=60, color=window_color)
    
    if is_save:
#         plt.savefig('../../应用/Overleaf/'+floder+'/figs/' + title + '.eps',format='eps',bbox_inches = 'tight')
        plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/ZC_' + title + '.pdf',format='pdf',bbox_inches = 'tight')
    plt.show()
grid_size = 8
bits_str = 'YXYXYX'[::-1]
colors = ["red", "blue", "red", "blue"]
w1 = patches.Rectangle((0.05, 0.05),1.95,4, linewidth=4, edgecolor=window_color, facecolor='none')
w2 = patches.Rectangle((4.05, 6.05),3.9,1.9, linewidth=4, edgecolor=window_color, facecolor='none')
w3 = patches.Rectangle((4.05, 0.05),3.9,0.95, linewidth=4, edgecolor=window_color, facecolor='none')
windows=[w1, w2, w3]
plot_zc(grid_size, get_points(grid_size, bits_str), colors, windows, bits_str[::-1])


grid_size = 8
bits_str = 'XYXYXY'[::-1]
colors = ["blue", "red", "blue", "red"]
w1 = patches.Rectangle((0.05, 0.05),1.95,4, linewidth=4, edgecolor=window_color, facecolor='none')
w2 = patches.Rectangle((4.05, 6.05),3.9,1.9, linewidth=4, edgecolor=window_color, facecolor='none')
w3 = patches.Rectangle((4.05, 0.05),3.9,0.95, linewidth=4, edgecolor=window_color, facecolor='none')
windows=[w1, w2, w3]
plot_zc(grid_size, get_points(grid_size, bits_str), colors, windows, bits_str[::-1])

grid_size = 8
bits_str = 'YYYXXX'[::-1]
colors = ["blue", "red", "blue", "red"]
w1 = patches.Rectangle((0.05, 0.05),1.95,4, linewidth=4, edgecolor=window_color, facecolor='none')
w2 = patches.Rectangle((4.05, 6.05),3.9,1.9, linewidth=4, edgecolor=window_color, facecolor='none')
w3 = patches.Rectangle((4.05, 0.05),3.9,0.95, linewidth=4, edgecolor=window_color, facecolor='none')
windows=[w1, w2, w3]
plot_zc(grid_size, get_points(grid_size, bits_str), colors, windows, bits_str[::-1])
# Out:
# YXYXYX
# 36
# XYXYXY
# 36
# YYYXXX
# 36

# %%
def plot_hc(grid_size, points, colors, windows=[], title=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax = plt.gca()

    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
    x = [0, 1, 2, 3]
    my_xticks = ['   0', '   1', '   2', '   3']
    plt.xticks(x, my_xticks, ha='left')
    ax.set_yticklabels(['0\n\n', '1\n\n', '2\n\n', '3\n\n'])
    plt.xticks([])
    ax.set_yticklabels([])
    plt.xlabel("x", fontsize=fontsize*1.5)
    plt.ylabel("y", fontsize=fontsize*1.5)
    ax.xaxis.set_label_coords(.5, -.01)
    ax.yaxis.set_label_coords(-.01, .5)

    if ax is None:
        ax = plt.gca()

    canvas = ax.figure.canvas

    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(24)
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(24)

    xs = []
    ys = []
    for i in range(grid_size * grid_size):
        xs.append(points[i][0] + 0.5)
        ys.append(points[i][1] + 0.5)

    for i in range(len(xs) - 1):
        is_in_window = False
        for window in windows:
            if window.xy[0] > xs[i]:
                continue
            if xs[i] > window.xy[0] + window.get_width():
                continue
            if window.xy[1] > ys[i]:
                continue
            if ys[i] > window.xy[1] + window.get_height():
                continue
            is_in_window = True
            if window.xy[0] > xs[i + 1]:
                is_in_window = False
            if xs[i + 1] > window.xy[0] + window.get_width():
                is_in_window = False
            if window.xy[1] > ys[i + 1]:
                is_in_window = False
            if ys[i + 1] > window.xy[1] + window.get_height():
                is_in_window = False
            break

        if is_in_window:
            plt.plot(xs[i:i + 2],
                     ys[i:i + 2],
                     color='blue',
                     linestyle='-.',
                     linewidth=4)
        else:
            plt.plot(xs[i:i + 2],
                     ys[i:i + 2],
                     color='lightgray',
                     linestyle='-.',
                     linewidth=4)
            
    plt.scatter(xs[-1], ys[-1],color='blue',linewidths=1)


    for i in range(0, grid_size - 1, 1):
        plt.plot([i + 1, i + 1], [0, grid_size],
                 color='lightgray',
                 linestyle='-',
                 linewidth=1)
    ax.grid(True, linestyle='solid', linewidth=1)

    for index, window in enumerate(windows):
        ax.add_patch(window)
        #
        plt.text(window.xy[0] + 0.1,
                 window.xy[1] + 0.2,
                 '$q_' + str(index + 1) + '$',
                 fontsize=30,
                 color=window_color)

#     if is_save:
        #         plt.savefig('../../应用/Overleaf/'+floder+'/figs/' + title + '.eps',format='eps',bbox_inches = 'tight')
#         plt.savefig('../../../../应用/Overleaf/' + floder + '/figs/HC_' + '.pdf',
#                     format='pdf',
#                     bbox_inches='tight')
    plt.show()


grid_size = 8
bits_str = 'YXXY'[::-1]
colors = ["blue", "red", "red", "blue"]

hilbert_curve = HilbertCurve(3, 2)
distances = list(range(grid_size * grid_size))
points = hilbert_curve.points_from_distances(distances)
w1 = patches.Rectangle((0.05, 0.05),
                       1.95,
                       4,
                       linewidth=4,
                       edgecolor=window_color,
                       facecolor='none')
w2 = patches.Rectangle((4.05, 6.05),
                       3.9,
                       1.9,
                       linewidth=4,
                       edgecolor=window_color,
                       facecolor='none')
w3 = patches.Rectangle((4.05, 0.05),
                       3.9,
                       0.95,
                       linewidth=4,
                       edgecolor=window_color,
                       facecolor='none')
windows = [w1, w2, w3]
plot_hc(grid_size, points, colors, windows, bits_str[::-1])

# %%
def plot_bmc(grid_size, points, colors, title="", tag=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax=plt.gca()

    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
    x=[0,1,2,3,4,5,6,7]
    my_xticks = ['  000','  001','  010','  011', '  100','  101','  110','  111']
    plt.xticks(x, my_xticks, ha='left')
    ax.set_yticklabels(['000\n\n','001\n\n','010\n\n','011\n\n','100\n\n','101\n\n','110\n\n','111\n\n'])

    ax.tick_params(axis='x', colors='red')   
    ax.tick_params(axis='y', colors='blue')
    
#     plt.xlabel("x", fontsize=24)
#     plt.ylabel("y", fontsize=24)

    if ax is None:
        ax = plt.gca()
#     ax.tick_params(axis='x', pad=30)
    
    canvas = ax.figure.canvas
    
    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(24)
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(24) 

    xs = []    
    ys = []
    for i in range(grid_size * grid_size):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
        
        

    # Need to draw to update the text position.
    targets_str = [1, 5, 13, 31, 39]
    targets_end = [2, 6, 14, 32, 40]
    
    t = ax.transData
    for i in range(0, grid_size * grid_size - 1):
        number = i
        t = ax.transData
        if i in targets_str or i in targets_end:
            for j in range(len(title) - 1, -1, -1):
                if number & int(pow(2, j)) == 0:
                    s = 0
                else:
                    s = 1
                if i in targets_str: 
                    text = ax.text(xs[i]-0.45, ys[i] + 0.1, s, color=colors[j], transform=t, size=18)
                    plt.text(xs[i]-0.45, ys[i]-0.35, i, fontsize=24, color="black")
                    
                else:
                    text = ax.text(xs[i]-0.45, ys[i] - 0.4, s, color=colors[j], transform=t, size=18)
                    plt.text(xs[i]+0.05, ys[i]+0.05, i, fontsize=24, color="black")
                text.draw(canvas.get_renderer())
                ex = text.get_window_extent()    
                t = text.get_transform() + Affine2D().translate(ex.width, 0)
        
    text = ax.text(2.4, 8.2, "BMC", color="black", transform=t, size=22)
    for char in title:
        c = "red"
        if char == "Y":
            c = "blue"
        text = ax.text(3.4, 8.2, char, color=c, transform=t, size=22)
        text.draw(canvas.get_renderer())
        ex = text.get_window_extent()    
        t = text.get_transform() + Affine2D().translate(ex.width, 0)
        
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    for i in range(len(xs)):
        if i not in [1,4,5,6,12,13,14,31,36,39]:
            continue
        if (i < len(xs) - 1 and xs[i+1] - xs[i] == 1):
            plt.plot(xs[i:i+2], ys[i:i+2], color='red', linestyle='-.', linewidth=4)
        else:
            plt.plot(xs[i:i+2], ys[i:i+2], color='black', linestyle='-.', linewidth=4)
            
#     plt.plot([3.5,4.5], [7.5,0.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([0.5,3.5], [4.5,3.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([5.5,6.5], [3.5,0.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([0.5,1.5], [1.5,0.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([4.5,5.5], [6.5,5.5], color='red', linestyle='-.', linewidth=4)
    window = patches.Rectangle((0.05, 2.05),
                       4.9,
                       1.9,
                       linewidth=4,
                       edgecolor="purple",
                       facecolor='none')
    ax.add_patch(window)
    #
    plt.text(window.xy[0] + 0.1,
             window.xy[1] + 0.2,
             '$q$',
             fontsize=30,
             color="purple")
    plt.text(1,3, '$s_1$', fontsize=30, color="purple")
    plt.text(3,3, '$s_2$', fontsize=30, color="purple")
    plt.text(0.6,2.8, '$e_1$', fontsize=30, color="red")
    plt.text(2.6,2.8, '$e_2$', fontsize=30, color="red")
    plt.text(4.5,2.7, '$s_3$', fontsize=30, color="purple")
    
    if title.startswith('X'):
        ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    else:
        ax.arrow(7.6, 7.5, 0.01, 0, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    
    for i in range(0, grid_size - 1, 1):
        plt.plot([i + 1, i + 1], [0,grid_size], color='lightgray', linestyle='-',linewidth = 1)
    ax.grid(True, linestyle='solid',linewidth=1)
    plt.xlabel("x", fontsize=fontsize)
    plt.ylabel("y", fontsize=fontsize)
    ax.xaxis.set_label_coords(.5, -.01)
    ax.yaxis.set_label_coords(-.05, .5)
#     if is_save:
# #         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/' + title + '.eps',format='eps',bbox_inches = 'tight')
#     plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/' + title + "_" + tag + '.svg',format='svg',bbox_inches = 'tight')
    plt.show()

# %%
grid_size = 8
bits_str = 'XYXYXY'[::-1]
colors = ["blue", "red", "blue", "red", "blue", "red", "blue", "red"]
plot_bmc(grid_size, get_points(grid_size, bits_str), colors, bits_str[::-1], "1")
# Out:
# XYXYXY

# %%
def plot_bmc(grid_size, points, colors, title="", tag=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax=plt.gca()

    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
    x=[0,1,2,3,4,5,6,7]
    my_xticks = ['  000','  001','  010','  011', '  100','  101','  110','  111']
    plt.xticks(x, my_xticks, ha='left')
    ax.set_yticklabels(['000\n\n','001\n\n','010\n\n','011\n\n','100\n\n','101\n\n','110\n\n','111\n\n'])

    ax.tick_params(axis='x', colors='red')   
    ax.tick_params(axis='y', colors='blue')
    
#     plt.xlabel("x", fontsize=24)
#     plt.ylabel("y", fontsize=24)

    if ax is None:
        ax = plt.gca()
#     ax.tick_params(axis='x', pad=30)
    
    canvas = ax.figure.canvas
    
    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(24)
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(24) 

    xs = []    
    ys = []
    for i in range(grid_size * grid_size):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
        
        

    # Need to draw to update the text position.
    targets_str = [ 5, 13]
    targets_end = [ 6, 14]
    
    t = ax.transData
    for i in range(0, grid_size * grid_size - 1):
        number = i
        t = ax.transData
        if i in targets_str or i in targets_end:
            for j in range(len(title) - 1, -1, -1):
                if number & int(pow(2, j)) == 0:
                    s = 0
                else:
                    s = 1
                if i in targets_str: 
                    text = ax.text(xs[i]-0.45, ys[i] + 0.1, s, color=colors[j], transform=t, size=18)
                    plt.text(xs[i]-0.45, ys[i]-0.35, i, fontsize=24, color="black")
                    
                else:
                    text = ax.text(xs[i]-0.45, ys[i] - 0.4, s, color=colors[j], transform=t, size=18)
                    plt.text(xs[i]+0.05, ys[i]+0.05, i, fontsize=24, color="black")
                text.draw(canvas.get_renderer())
                ex = text.get_window_extent()    
                t = text.get_transform() + Affine2D().translate(ex.width, 0)
        
    text = ax.text(2.4, 8.2, "BMC", color="black", transform=t, size=22)
    for char in title:
        c = "red"
        if char == "Y":
            c = "blue"
        text = ax.text(3.4, 8.2, char, color=c, transform=t, size=22)
        text.draw(canvas.get_renderer())
        ex = text.get_window_extent()    
        t = text.get_transform() + Affine2D().translate(ex.width, 0)
        
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    for i in range(len(xs)):
        if i not in [5,6,12,13]:
            continue
        if (i < len(xs) - 1 and xs[i+1] - xs[i] == 1):
            plt.plot(xs[i:i+2], ys[i:i+2], color='red', linestyle='-.', linewidth=4)
#         else:
#             plt.plot(xs[i:i+2], ys[i:i+2], color='black', linestyle='-.', linewidth=4)
            
#     plt.plot([3.5,4.5], [7.5,0.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([0.5,3.5], [4.5,3.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([5.5,6.5], [3.5,0.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([0.5,1.5], [1.5,0.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([4.5,5.5], [6.5,5.5], color='red', linestyle='-.', linewidth=4)
    window = patches.Rectangle((0.05, 2.05),
                       4.9,
                       1.9,
                       linewidth=4,
                       edgecolor="purple",
                       facecolor='none')
    ax.add_patch(window)
    #
#     plt.text(window.xy[0] + 0.1,
#              window.xy[1] + 0.2,
#              '$q$',
#              fontsize=30,
#              color="purple")
#     plt.text(1,3, '$s_1$', fontsize=30, color="purple")
#     plt.text(3,3, '$s_2$', fontsize=30, color="purple")
    plt.text(0.6,2.8, '$e_1$', fontsize=30, color="red")
    plt.text(2.6,2.8, '$e_2$', fontsize=30, color="red")
#     plt.text(4.5,2.7, '$s_3$', fontsize=30, color="purple")
    
    if title.startswith('X'):
        ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    else:
        ax.arrow(7.6, 7.5, 0.01, 0, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    
    for i in range(0, grid_size - 1, 1):
        plt.plot([i + 1, i + 1], [0,grid_size], color='lightgray', linestyle='-',linewidth = 1)
    ax.grid(True, linestyle='solid',linewidth=1)
    plt.xlabel("x", fontsize=fontsize)
    plt.ylabel("y", fontsize=fontsize)
    ax.xaxis.set_label_coords(.5, -.01)
    ax.yaxis.set_label_coords(-.05, .5)
#     if is_save:
# #         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/' + title + '.eps',format='eps',bbox_inches = 'tight')
#     plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/' + title + "_" + tag + '.svg',format='svg',bbox_inches = 'tight')
    plt.show()
grid_size = 8
bits_str = 'XYXYXY'[::-1]
colors = ["blue", "red", "blue", "red", "blue", "red", "blue", "red"]
plot_bmc(grid_size, get_points(grid_size, bits_str), colors, bits_str[::-1], "1")
# Out:
# XYXYXY

# %%
def plot_bmc(grid_size, points, colors, title="", tag=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax=plt.gca()

    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
    x=[0,1,2,3,4,5,6,7]
    my_xticks = ['  000','  001','  010','  011', '  100','  101','  110','  111']
    plt.xticks(x, my_xticks, ha='left')
    ax.set_yticklabels(['000\n\n','001\n\n','010\n\n','011\n\n','100\n\n','101\n\n','110\n\n','111\n\n'])

    ax.tick_params(axis='x', colors='red')   
    ax.tick_params(axis='y', colors='blue')
    
#     plt.xlabel("x", fontsize=24)
#     plt.ylabel("y", fontsize=24)

    if ax is None:
        ax = plt.gca()
#     ax.tick_params(axis='x', pad=30)
    
    canvas = ax.figure.canvas
    
    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(24)
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(24) 

    xs = []    
    ys = []
    for i in range(grid_size * grid_size):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
        
        

    # Need to draw to update the text position.
    targets_str = [1, 12, 47]
    targets_end = [0, 11, 48]
    
    t = ax.transData
    for i in range(0, grid_size * grid_size - 1):
        number = i
        t = ax.transData
        if i in targets_str or i in targets_end:
            for j in range(len(title) - 1, -1, -1):
                if number & int(pow(2, j)) == 0:
                    s = 0
                else:
                    s = 1
                if i in targets_str: 
                    text = ax.text(xs[i]-0.45, ys[i] + 0.1, s, color=colors[j], transform=t, size=18)
                    plt.text(xs[i]-0.45, ys[i]-0.35, i, fontsize=24, color="black")
                    
                else:
                    text = ax.text(xs[i]-0.45, ys[i] - 0.4, s, color=colors[j], transform=t, size=18)
                    plt.text(xs[i]+0.05, ys[i]+0.05, i, fontsize=24, color="black")
                text.draw(canvas.get_renderer())
                ex = text.get_window_extent()    
                t = text.get_transform() + Affine2D().translate(ex.width, 0)
        
    text = ax.text(2.4, 8.2, "BMC", color="black", transform=t, size=22)
    for char in title:
        c = "red"
        if char == "Y":
            c = "blue"
        text = ax.text(3.4, 8.2, char, color=c, transform=t, size=22)
        text.draw(canvas.get_renderer())
        ex = text.get_window_extent()    
        t = text.get_transform() + Affine2D().translate(ex.width, 0)
        
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    for i in range(len(xs)):
        if i not in [0, 4,5,6,11,12,13,14, 36,47]:
            continue
        if (i < len(xs) - 1 and xs[i+1] - xs[i] == 1):
            plt.plot(xs[i:i+2], ys[i:i+2], color='red', linestyle='-.', linewidth=4)
        else:
            plt.plot(xs[i:i+2], ys[i:i+2], color='black', linestyle='-.', linewidth=4)
            
#     plt.plot([3.5,4.5], [7.5,0.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([0.5,3.5], [4.5,3.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([5.5,6.5], [3.5,0.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([0.5,1.5], [1.5,0.5], color='red', linestyle='-.', linewidth=4)
#     plt.plot([4.5,5.5], [6.5,5.5], color='red', linestyle='-.', linewidth=4)
    window = patches.Rectangle((0.05, 2.05),
                       4.9,
                       1.9,
                       linewidth=4,
                       edgecolor="purple",
                       facecolor='none')
    ax.add_patch(window)
    #
    plt.text(window.xy[0] + 0.1,
             window.xy[1] + 0.2,
             '$q$',
             fontsize=30,
             color="purple")
    plt.text(1,3, '$s_1$', fontsize=30, color="purple")
    plt.text(3,3, '$s_2$', fontsize=30, color="purple")
    plt.text(4.5,2.7, '$s_3$', fontsize=30, color="purple")
    if title.startswith('X'):
        ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    else:
        ax.arrow(7.6, 7.5, 0.01, 0, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    
    for i in range(0, grid_size - 1, 1):
        plt.plot([i + 1, i + 1], [0,grid_size], color='lightgray', linestyle='-',linewidth = 1)
    ax.grid(True, linestyle='solid',linewidth=1)
    plt.xlabel("x", fontsize=fontsize)
    plt.ylabel("y", fontsize=fontsize)
    ax.xaxis.set_label_coords(.5, -.01)
    ax.yaxis.set_label_coords(-.05, .5)
#     if is_save:
# #         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/' + title + '.eps',format='eps',bbox_inches = 'tight')
#     plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/' + title + "_" + tag + '.svg',format='svg',bbox_inches = 'tight')
    plt.show()

# %%
grid_size = 8
bits_str = 'XYXYXY'[::-1]
colors = ["blue", "red", "blue", "red", "blue", "red", "blue", "red"]
plot_bmc(grid_size, get_points(grid_size, bits_str), colors, bits_str[::-1], "2")
# Out:
# XYXYXY

# %%
# def plot_z_curve_section_demo(grid_size, points, windows=None, title=""):
#     fig = plt.figure(1, (grid_size, grid_size))
#     ax=plt.gca()
#     # ax = SubplotZero(fig, 1, 1, 1)
# #     fig.add_subplot(ax)
#     ax.set_ylim([0, grid_size])
#     ax.set_xlim([0, grid_size])
#     x=[0,1,2,3,4,5,6,7]
#     my_xticks = ['   0','   1','   2','   3','   4','   5','   6','   7']
#     plt.xticks(x, my_xticks, ha='left')
#     ax.set_yticklabels(['0\n\n','1\n\n','2\n\n','3\n\n','4\n\n','5\n\n','6\n\n','7\n\n'])

#     for tick in ax.xaxis.get_major_ticks():
#         tick.label.set_fontsize(fontsize) 
#     for tick in ax.yaxis.get_major_ticks():
#         tick.label.set_fontsize(fontsize) 
#     ax.grid(True, linestyle='solid',linewidth=1)
    

# #     for i in range(grid_size):
# #         for j in range(grid_size):
# #             plt.scatter(i + 0.5, j + 0.5,color='r',linewidths=4)


    
#     xs = []    
#     ys = []
#     for i in range(15):
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    
#     xs = []    
#     ys = []
#     for i in range(15, 37):
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='lightgray', linestyle='-', linewidth=4)
    
#     xs = []    
#     ys = []
#     for i in range(39, 45):
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='lightgray', linestyle='-', linewidth=4)
    
#     xs = []    
#     ys = []
#     for i in range(45, 64):
        
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
#     plt.xlabel("x", fontsize=fontsize)
#     plt.ylabel("y", fontsize=fontsize)
#     for window in windows:
#         ax.add_patch(window)     
#     plt.arrow(3.5, 2.5, 0, 0.8, color=section_color, width = 0.05)
    
#     plt.arrow(4.5, 2.5, 0, 0.8, color=section_color, width = 0.05)
#     plt.arrow(4.5, 3.5, 0.8, -0.8, color=section_color, width = 0.05)
#     plt.arrow(5.5, 2.5, 0, 0.8, color=section_color, width = 0.05)
    
#     plt.arrow(6.5, 2.5, 0, 0.8, color=section_color, width = 0.05)
#     plt.text(7.1, 2.2, '$q$', fontsize=32,color=window_color)
# #     plt.text(3.3, 2.1, '$p_s$', fontsize=32,color="black")
# #     plt.text(6.3, 3.6, '$p_e$', fontsize=32,color="black")
#     plt.text(3.5, 2.3, '$s_1$', fontsize=32,color="purple")
#     plt.text(5.1, 2.3, '$s_2$', fontsize=32,color="purple")
#     plt.text(6.5, 2.3, '$s_3$', fontsize=32,color="purple")
#     plt.text(2.95, 2.8, '$e_1$', fontsize=32,color="red")
#     plt.text(3.8, 2.8, '$e_2$', fontsize=32,color="red")
#     plt.text(4.9, 3.0, '$e_3$', fontsize=32,color="red")
#     plt.text(5.55, 2.8, '$e_4$', fontsize=32,color="red")
#     plt.text(6.45, 2.8, '$e_5$', fontsize=32,color="red")
    
# #     plt.text(1.7, 5.0, '$I_1$', fontsize=32,color="green")
# #     plt.text(7.1, 1.2, '$I_2$', fontsize=32,color="green")
# #     plt.text(0.2, 0.1, 'start', fontsize=24)
# #     plt.text(7.2, 7.7, 'end', fontsize=24)
#     plt.text(4.6, 2.2, '$p_i$', fontsize=32,color="black")
#     plt.text(5.0, 1.2, '$p_{i-1}$', fontsize=32,color="black")
#     plt.text(5.0, 3.6, '$p_j$', fontsize=32,color="black")
#     plt.text(6.0, 0.2, '$p_{j+1}$', fontsize=32,color="black")
# #     plt.text(6.0, 2.2, '$p_{o}$', fontsize=32,color="black")
#     plt.scatter(4 + 0.5, 2 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(5 + 0.5, 1 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(5 + 0.5, 3 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(6 + 0.5, 0 + 0.5,color=point_color,linewidths=4)
# #     plt.scatter(6 + 0.5, 2 + 0.5,color=point_color,linewidths=4)
# #     plt.scatter(3 + 0.5, 2 + 0.5,color=point_color,linewidths=4)
# #     plt.scatter(6 + 0.5, 3 + 0.5,color=point_color,linewidths=4)
# #     plt.scatter(0 + 0.5, 4 + 0.5,color=point_color,linewidths=4)
# #     plt.scatter(4 + 0.5, 0 + 0.5,color=point_color,linewidths=4)
# #     plt.scatter(4 + 0.5, 4 + 0.5,color=point_color,linewidths=4)
    
# #     plt.text(4.0, 0.0, '$32$', color=text_colot,fontsize=26)
# #     plt.text(0.0, 4.0, '$16$', color=text_colot,fontsize=26)
# #     plt.text(4.0, 4.0, '$48$', color=text_colot,fontsize=26)
# #     plt.text(6.5, 2.6, '$44$', color=text_colot,fontsize=26)
#     plt.text(6.5, 0.6, '$40$', color=text_colot,fontsize=26)
#     plt.text(5.5, 3.6, '$39$', color=text_colot,fontsize=26)
#     plt.text(5.3, 1.6, '$35$', color=text_colot,fontsize=26)
#     plt.text(4.0, 2.0, '$36$', color=text_colot,fontsize=26)
# #     plt.plot([1,1], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
# #     plt.plot([3,3], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
# #     plt.plot([5,5], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
# #     plt.plot([7,7], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
#     #         ax.arrow(7.5, 7.5, 0.01, 0, head_width=0.3, head_length=0.3, fc='gray', ec='gray', fill=False)
#     ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
# #     plt.title("Bit-sequence XYXYXY", fontsize=fontsize)
#     ax.xaxis.set_label_coords(.5, -.06)
# #     if is_save:
# # #         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval.eps',format='eps',bbox_inches = 'tight')
# #         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval.pdf',format='pdf',bbox_inches = 'tight')

# grid_size = 8
# bits_str = 'XXYYXY'[::-1]
# bits_str = 'XYXYXY'[::-1]
# w1 = patches.Rectangle((3, 2),4,2, linewidth=4,edgecolor=window_color,facecolor='none')
# windows=[w1]
# plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, bits_str[::-1])
# Out:
# XYXYXY

# %%
def plot_z_curve_section_demo(grid_size, points, windows=None, title=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax=plt.gca()
    # ax = SubplotZero(fig, 1, 1, 1)
#     fig.add_subplot(ax)
    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
    x=[0,1,2,3,4,5,6,7]
    my_xticks = ['   0','   1','   2','   3','   4','   5','   6','   7']
    plt.xticks(x, my_xticks, ha='left')
    ax.set_yticklabels(['0\n\n','1\n\n','2\n\n','3\n\n','4\n\n','5\n\n','6\n\n','7\n\n'])

    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize) 
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize) 
    ax.grid(True, linestyle='solid',linewidth=1)
    
    xs = []    
    ys = []
    for i in range(15):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(15, 37):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(39, 45):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(45, 64):
        
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    plt.xlabel("x", fontsize=fontsize)
    plt.ylabel("y", fontsize=fontsize)
    for window in windows:
        ax.add_patch(window)     
    plt.arrow(3.5, 2.5, 0, 0.8, color="blue", width = 0.05)
    
    plt.arrow(4.5, 2.5, 0, 0.8, color="blue", width = 0.05)
    plt.arrow(4.5, 3.5, 0.8, -0.8, color="blue", width = 0.05)
    plt.arrow(5.5, 2.5, 0, 0.8, color="blue", width = 0.05)
    
    plt.arrow(6.5, 2.5, 0, 0.8, color="blue", width = 0.05)
    plt.text(7.1, 2.2, '$q$', fontsize=40,color=window_color)



    plt.text(5.0, 1.2, '$p_{i-1}$', fontsize=40,color="black")
    plt.text(6.0, 0.2, '$p_{j+1}$', fontsize=40,color="black")

    plt.scatter(4 + 0.5, 2 + 0.5,color=point_color,linewidths=4)
    plt.scatter(5 + 0.5, 1 + 0.5,color=point_color,linewidths=4)
    plt.scatter(5 + 0.5, 3 + 0.5,color=point_color,linewidths=4)
    plt.scatter(6 + 0.5, 0 + 0.5,color=point_color,linewidths=4)

    plt.text(6.5, 0.6, '$40$', color=text_colot,fontsize=26)
    plt.text(5.0, 3.6, '$39$', color=text_colot,fontsize=26)
    plt.text(5.3, 1.6, '$35$', color=text_colot,fontsize=26)
    plt.text(4.0, 2.6, '$36$', color=text_colot,fontsize=26)

    ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    ax.xaxis.set_label_coords(.5, -.06)
    
    plt.text(1.5, 1.2, '$s_1$', fontsize=40,color="blue")
    verts = [(1.7, 1.6), (2.5, 2.5), (3.4, 3.0)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='blue', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((3.3, 3.0), (3.4, 2.9), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="blue")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(3.5, 0.2, '$s_2$', fontsize=40,color="blue")
    verts = [(3.9, 0.6), (5.6, 1.5), (4.9, 3.0)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='blue', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((5.0, 2.9), (4.9, 3.0), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="blue")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(7.3, 5.2, '$s_3$', fontsize=40,color="blue")
    verts = [(7.5, 5.1), (7.0, 3.9), (6.65, 3.1)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='blue', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((6.65, 3.1), (6.6, 3.2), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="blue")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(2.0, 3.2, '$e_1$', fontsize=40,color="black")
    verts = [(2.6, 3.2), (3.0, 3.4), (3.5, 3.2)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((3.4, 3.2), (3.5, 3.2), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(3.0, 4.7, '$e_2$', fontsize=40,color="black")
    verts = [(3.2, 4.6), (3.5, 4.0), (4.5, 3.0)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((4.4, 3.0), (4.5, 2.9), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(4.7, 4.7, '$e_3$', fontsize=40,color="black")
    verts = [(4.8, 4.6), (4.7, 4.2), (5.05, 3.1)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((5.0, 3.0), (5.1, 2.9), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(5.8, 4.7, '$e_4$', fontsize=40,color="black")
    verts = [(6.1, 4.6), (6.7, 4.0), (5.55, 2.9)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((5.6, 2.9), (5.55, 3.0), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(7.5, 2.5, '$e_5$', fontsize=40,color="black")
    verts = [(7.5, 2.7), (7.0, 3.0), (6.6, 2.7)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((6.6, 2.8), (6.5, 2.75), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(2.6, 1.2, '$p_i$', fontsize=40,color="black")
    verts = [(2.8, 1.6), (2.5, 2.5), (4.3, 2.45)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((4.4, 2.4), (4.5, 2.5), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    
    plt.text(5.0, 5.6, '$p_j$', fontsize=40,color="black")
    verts = [(5.6, 5.4), (6.0, 4.0), (5.6, 3.7)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((5.55, 3.7), (5.5, 3.6), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    
    if is_save:
#         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval.eps',format='eps',bbox_inches = 'tight')
        plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval.pdf',format='pdf',bbox_inches = 'tight')

grid_size = 8
bits_str = 'XXYYXY'[::-1]
bits_str = 'XYXYXY'[::-1]
w1 = patches.Rectangle((3, 2),4,2, linewidth=4,edgecolor=window_color,facecolor='none')
windows=[w1]
plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, bits_str[::-1])
# Out:
# XYXYXY

# %%
def plot_z_curve_section_demo(grid_size, points, windows=None, title=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax=plt.gca()
    # ax = SubplotZero(fig, 1, 1, 1)
#     fig.add_subplot(ax)
    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
    x=[0,1,2,3,4,5,6,7]
    my_xticks = ['   0','   1','   2','   3','   4','   5','   6','   7']
    plt.xticks(x, my_xticks, ha='left')
    ax.set_yticklabels(['0\n\n','1\n\n','2\n\n','3\n\n','4\n\n','5\n\n','6\n\n','7\n\n'])

    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize) 
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize) 
    ax.grid(True, linestyle='solid',linewidth=1)

#     for i in range(grid_size):
#         for j in range(grid_size):
#             plt.scatter(i + 0.5, j + 0.5,color='r',linewidths=4)

    xs = []    
    ys = []
    for i in range(14):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(13, 25):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(28, 31):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-', linewidth=4)
    
#     xs = []    
#     ys = []
#     for i in range(39, 45):
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='black', linestyle='-')
    
    xs = []    
    ys = []
    for i in range(30, 64):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    plt.xlabel("x", fontsize=fontsize)
    plt.ylabel("y", fontsize=fontsize)
    for window in windows:
        ax.add_patch(window)     
    plt.arrow(4.5, 2.5, 0.8, 0.0, color="blue", width = 0.05)
    plt.arrow(5.5, 2.5, -0.8, 0.8, color="blue", width = 0.05)
    plt.arrow(4.5, 3.5, 0.8, 0.0, color="blue", width = 0.05)
    plt.arrow(5.5, 3.5, 0.8, -0.8, color="blue", width = 0.05)
    

    plt.text(7.1, 2.2, '$q$', fontsize=40,color=window_color)

    plt.scatter(3 + 0.5, 2 + 0.5,color="blue",linewidths=4)
    plt.scatter(3 + 0.5, 3 + 0.5,color="blue",linewidths=4)
    plt.scatter(6 + 0.5, 3 + 0.5,color="blue",linewidths=4)
    plt.plot([1,1], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
    plt.plot([3,3], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
    plt.plot([5,5], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
    plt.plot([7,7], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
    ax.arrow(7.5, 7.5, 0.01, 0, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
#     plt.title("Bit-sequence YXYXYX", fontsize=fontsize)

    plt.text(3.1, 0.6, '$s_1$', fontsize=40,color="blue")
    verts = [(3.2, 1.0), (2.8, 2.0), (3.4, 2.4)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='blue', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((3.4, 2.25), (3.5, 2.4), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="blue")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(3.0, 4.8, '$s_2$', fontsize=40,color="blue")
    verts = [(3.2, 4.6), (2.8, 4.0), (3.4, 3.7)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='blue', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((3.4, 3.6), (3.5, 3.55), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="blue")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(6.0, 0.6, '$s_3$', fontsize=40,color="blue")
    verts = [(6.2, 1.0), (5.8, 2.0), (5.8, 2.8)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='blue', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((5.9, 2.8), (5.9, 2.9), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="blue")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(6.0, 4.8, '$s_4$', fontsize=40,color="blue")
    verts = [(6.2, 4.6), (5.8, 4.0), (6.4, 3.7)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='blue', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((6.4, 3.6), (6.5, 3.55), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="blue")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    
    plt.text(4.4, 4.8, '$e_3$', fontsize=40,color="black")
    verts = [(4.8, 4.6), (4.7, 4.2), (5.05, 3.7)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((5.0, 3.6), (5.1, 3.5), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(4.4, 0.6, '$e_1$', fontsize=40,color="black")
    verts = [(4.8, 0.9), (4.7, 1.2), (5.05, 2.4)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((5.1, 2.4), (5.1, 2.5), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    

    plt.text(2.1, 2.8, '$e_2$', fontsize=40,color="black")
    verts = [(2.7, 2.85), (4.7, 2.8), (4.9, 2.85)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((5.0, 2.8), (5.1, 2.85), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    
    plt.text(7.3, 2.8, '$e_4$', fontsize=40,color="black")
    verts = [(7.3, 2.85), (6.7, 2.8), (6.3, 2.85)]  # 顶点坐标
    codes = [Path.MOVETO, Path.CURVE3, Path.CURVE3]  # 路径类型
    path = Path(verts, codes)
    patch = patches.PathPatch(path, linestyle='--', edgecolor='black', linewidth=3, fill=False)
    arrow = patches.FancyArrowPatch((6.25, 2.9), (6.15, 2.9), connectionstyle="arc3,rad=-0.5", mutation_scale=15, linestyle='--', color="black")
    ax.add_patch(patch)
    ax.add_patch(arrow)
    

    ax.xaxis.set_label_coords(.5, -.06)
#     ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
    if is_save:
#         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval_bit_distribution.eps',format='eps',bbox_inches = 'tight')
        plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval_bit_distribution.pdf',format='pdf',bbox_inches = 'tight')

grid_size = 8
bits_str = 'XXYYXY'[::-1]
bits_str = 'YXYXYX'[::-1]
w1 = patches.Rectangle((3, 2),4,2, linewidth=4,edgecolor=window_color,facecolor='none')
windows=[w1]
plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, bits_str[::-1])
# Out:
# YXYXYX

# %%
def plot_z_curve_section_demo(grid_size, points, windows=None, title=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax=plt.gca()
    # ax = SubplotZero(fig, 1, 1, 1)
#     fig.add_subplot(ax)
    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
    x=[0,1,2,3,4,5,6,7]
    my_xticks = ['   0','   1','   2','   3','   4','   5','   6','   7']
    plt.xticks(x, my_xticks, ha='left')
    ax.set_yticklabels(['0\n\n','1\n\n','2\n\n','3\n\n','4\n\n','5\n\n','6\n\n','7\n\n'])

    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize) 
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize) 
    ax.grid(True, linestyle='solid',linewidth=1)
    

#     for i in range(grid_size):
#         for j in range(grid_size):
#             plt.scatter(i + 0.5, j + 0.5,color='r',linewidths=4)


    
    xs = []    
    ys = []
    for i in range(15):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(15, 37):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='blue', linestyle='-', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(39, 45):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='blue', linestyle='-', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(45, 64):
        
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    plt.xlabel("x", fontsize=fontsize)
    plt.ylabel("y", fontsize=fontsize)
    for window in windows:
        ax.add_patch(window)     
    plt.arrow(3.5, 2.5, 0, 0.8, color=section_color, width = 0.05)
    
    plt.arrow(4.5, 2.5, 0, 0.8, color=section_color, width = 0.05)
    plt.arrow(4.5, 3.5, 0.8, -0.8, color=section_color, width = 0.05)
    plt.arrow(5.5, 2.5, 0, 0.8, color=section_color, width = 0.05)
    
    plt.arrow(6.5, 2.5, 0, 0.8, color=section_color, width = 0.05)
    plt.text(7.1, 2.2, '$q$', fontsize=32,color=window_color)
#     plt.text(3.3, 2.1, '$p_s$', fontsize=32,color="black")
#     plt.text(6.3, 3.6, '$p_e$', fontsize=32,color="black")
#     plt.text(3.5, 2.3, '$s_1$', fontsize=32,color="purple")
#     plt.text(5.1, 2.3, '$s_2$', fontsize=32,color="purple")
#     plt.text(6.5, 2.3, '$s_3$', fontsize=32,color="purple")
    plt.text(2.95, 2.8, '$e_1$', fontsize=32,color="red")
    plt.text(3.8, 2.8, '$e_2$', fontsize=32,color="red")
    plt.text(4.9, 3.0, '$e_3$', fontsize=32,color="red")
    plt.text(5.55, 2.8, '$e_4$', fontsize=32,color="red")
    plt.text(6.45, 2.8, '$e_5$', fontsize=32,color="red")
    
#     plt.text(1.7, 5.0, '$I_1$', fontsize=32,color="green")
#     plt.text(7.1, 1.2, '$I_2$', fontsize=32,color="green")
#     plt.text(0.2, 0.1, 'start', fontsize=24)
#     plt.text(7.2, 7.7, 'end', fontsize=24)
#     plt.text(4.6, 2.2, '$p_i$', fontsize=32,color="black")
#     plt.text(5.0, 1.2, '$p_{i-1}$', fontsize=32,color="black")
#     plt.text(5.0, 3.6, '$p_j$', fontsize=32,color="black")
#     plt.text(6.0, 0.2, '$p_{j+1}$', fontsize=32,color="black")
#     plt.text(6.0, 2.2, '$p_{o}$', fontsize=32,color="black")
#     plt.scatter(4 + 0.5, 2 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(5 + 0.5, 1 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(5 + 0.5, 3 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(6 + 0.5, 0 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(6 + 0.5, 2 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(3 + 0.5, 2 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(6 + 0.5, 3 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(0 + 0.5, 4 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(4 + 0.5, 0 + 0.5,color=point_color,linewidths=4)
#     plt.scatter(4 + 0.5, 4 + 0.5,color=point_color,linewidths=4)
    
#     plt.text(4.0, 0.0, '$32$', color=text_colot,fontsize=26)
#     plt.text(0.0, 4.0, '$16$', color=text_colot,fontsize=26)
#     plt.text(4.0, 4.0, '$48$', color=text_colot,fontsize=26)
#     plt.text(6.5, 2.6, '$44$', color=text_colot,fontsize=26)
#     plt.text(6.5, 0.6, '$40$', color=text_colot,fontsize=26)
#     plt.text(5.5, 3.6, '$39$', color=text_colot,fontsize=26)
#     plt.text(5.3, 1.6, '$35$', color=text_colot,fontsize=26)
#     plt.text(4.0, 2.0, '$36$', color=text_colot,fontsize=26)
#     plt.plot([1,1], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
#     plt.plot([3,3], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
#     plt.plot([5,5], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
#     plt.plot([7,7], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
    #         ax.arrow(7.5, 7.5, 0.01, 0, head_width=0.3, head_length=0.3, fc='gray', ec='gray', fill=False)
    ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
#     plt.title("Bit-sequence XYXYXY", fontsize=fontsize)
    ax.xaxis.set_label_coords(.5, -.06)
#     if is_save:
# #         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval.eps',format='eps',bbox_inches = 'tight')
#         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval.pdf',format='pdf',bbox_inches = 'tight')

grid_size = 8
bits_str = 'XXYYXY'[::-1]
bits_str = 'XYXYXY'[::-1]
w1 = patches.Rectangle((3, 2),4,2, linewidth=4,edgecolor=window_color,facecolor='none')
windows=[w1]
plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, bits_str[::-1])
# Out:
# XYXYXY

# %%
# def plot_z_curve_section_demo(grid_size, points, windows=None, title=""):
#     fig = plt.figure(1, (grid_size, grid_size))
#     ax=plt.gca()
#     # ax = SubplotZero(fig, 1, 1, 1)
# #     fig.add_subplot(ax)
#     ax.set_ylim([0, grid_size])
#     ax.set_xlim([0, grid_size])
#     x=[0,1,2,3,4,5,6,7]
#     my_xticks = ['   0','   1','   2','   3','   4','   5','   6','   7']
#     plt.xticks(x, my_xticks, ha='left')
#     ax.set_yticklabels(['0\n\n','1\n\n','2\n\n','3\n\n','4\n\n','5\n\n','6\n\n','7\n\n'])

#     for tick in ax.xaxis.get_major_ticks():
#         tick.label.set_fontsize(fontsize) 
#     for tick in ax.yaxis.get_major_ticks():
#         tick.label.set_fontsize(fontsize) 
#     ax.grid(True, linestyle='solid',linewidth=1)

# #     for i in range(grid_size):
# #         for j in range(grid_size):
# #             plt.scatter(i + 0.5, j + 0.5,color='r',linewidths=4)

#     xs = []    
#     ys = []
#     for i in range(14):
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    
#     xs = []    
#     ys = []
#     for i in range(13, 25):
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='lightgray', linestyle='-', linewidth=4)
    
#     xs = []    
#     ys = []
#     for i in range(28, 31):
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='lightgray', linestyle='-', linewidth=4)
    
# #     xs = []    
# #     ys = []
# #     for i in range(39, 45):
# #         xs.append(points[i].xs[0]+0.5)
# #         ys.append(points[i].xs[1]+0.5)
# #     plt.plot(xs, ys, color='black', linestyle='-')
    
#     xs = []    
#     ys = []
#     for i in range(30, 64):
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
#     plt.xlabel("x", fontsize=fontsize)
#     plt.ylabel("y", fontsize=fontsize)
#     for window in windows:
#         ax.add_patch(window)     
#     plt.arrow(4.5, 2.5, 0.8, 0.0, color=section_color, width = 0.05)
#     plt.arrow(5.5, 2.5, -0.8, 0.8, color=section_color, width = 0.05)
#     plt.arrow(4.5, 3.5, 0.8, 0.0, color=section_color, width = 0.05)
#     plt.arrow(5.5, 3.5, 0.8, -0.8, color=section_color, width = 0.05)
    
    
# #     plt.arrow(4.5, 2.5, 0, 0.8, color='red', width = 0.05)
# #     plt.arrow(4.5, 3.5, 0.8, -0.8, color='red', width = 0.05)
# #     plt.arrow(5.5, 2.5, 0, 0.8, color='red', width = 0.05)
    
# #     plt.arrow(6.5, 2.5, 0, 0.8, color='red', width = 0.05)
#     plt.text(7.1, 2.2, '$q$', fontsize=30,color=window_color)
# #     plt.text(3.3, 2.1, '$p_s$', fontsize=30)
# #     plt.text(6.3, 3.6, '$p_e$', fontsize=30)
#     plt.text(3.1, 2.1, '$s_1$', fontsize=30,color="purple")
#     plt.text(3.0, 3.0, '$s_2$', fontsize=30,color="purple")
#     plt.text(6.0, 2.2, '$s_3$', fontsize=30,color="purple")
#     plt.text(6.3, 2.9, '$s_4$', fontsize=30,color="purple")
#     plt.text(4.4, 2.1, '$e_1$', fontsize=30,color="red")
#     plt.text(4.4, 2.8, '$e_2$', fontsize=30,color="red")
#     plt.text(4.4, 3.6, '$e_3$', fontsize=30,color="red")
#     plt.text(5.3, 2.8, '$e_4$', fontsize=30,color="red")
# #     plt.text(2.3, 2.9, '$I_1$', fontsize=30,color="green")
# #     plt.text(6.3, 0.9, '$I_2$', fontsize=30,color="green")
# #     plt.text(7.3, 2.9, '$I_3$', fontsize=30,color="green")
# #     plt.text(3.9, 3.5, '$I_1$', fontsize=30)
# #     plt.text(5.9, 1.5, '$I_2$', fontsize=30)
# #     plt.text(0.2, 0.1, 'start', fontsize=24)
# #     plt.text(7.2, 7.7, 'end', fontsize=24)
# #     plt.text(4.6, 2.2, '$p_i$', fontsize=30)
# #     plt.text(4.6, 1.2, '$p_{i-1}$', fontsize=30)
# #     plt.text(5.0, 3.6, '$p_j$', fontsize=30)
# #     plt.text(6.0, 0.2, '$p_{j+1}$', fontsize=30)
#     plt.scatter(3 + 0.5, 2 + 0.5,color=section_color,linewidths=4)
#     plt.scatter(3 + 0.5, 3 + 0.5,color=section_color,linewidths=4)
#     plt.scatter(6 + 0.5, 3 + 0.5,color=section_color,linewidths=4)
# #     plt.scatter(6 + 0.5, 2 + 0.5,color='black',linewidths=4)
# #     plt.scatter(4 + 0.5, 2 + 0.5,color='black',linewidths=4)
# #     plt.scatter(5 + 0.5, 1 + 0.5,color='r',linewidths=4)
# #     plt.scatter(5 + 0.5, 3 + 0.5,color='r',linewidths=4)
# #     plt.scatter(6 + 0.5, 0 + 0.5,color='r',linewidths=4)
#     plt.plot([1,1], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
#     plt.plot([3,3], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
#     plt.plot([5,5], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
#     plt.plot([7,7], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
#     ax.arrow(7.5, 7.5, 0.01, 0, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
# #     plt.title("Bit-sequence YXYXYX", fontsize=fontsize)
#     ax.xaxis.set_label_coords(.5, -.06)
# #     ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
#     if is_save:
# #         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval_bit_distribution.eps',format='eps',bbox_inches = 'tight')
#         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval_bit_distribution.pdf',format='pdf',bbox_inches = 'tight')

# grid_size = 8
# bits_str = 'XXYYXY'[::-1]
# bits_str = 'YXYXYX'[::-1]
# w1 = patches.Rectangle((3, 2),4,2, linewidth=4,edgecolor=window_color,facecolor='none')
# windows=[w1]
# plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, bits_str[::-1])
# Out:
# YXYXYX

# %%
def plot_z_curve_section_demo(grid_size, points, windows=None, title=""):
    fig = plt.figure(1, (grid_size, grid_size))
    ax=plt.gca()
    # ax = SubplotZero(fig, 1, 1, 1)
#     fig.add_subplot(ax)
    ax.set_ylim([0, grid_size])
    ax.set_xlim([0, grid_size])
    x=[0,1,2,3,4,5,6,7]
    my_xticks = ['   0','   1','   2','   3','   4','   5','   6','   7']
    plt.xticks(x, my_xticks, ha='left')
    ax.set_yticklabels(['0\n\n','1\n\n','2\n\n','3\n\n','4\n\n','5\n\n','6\n\n','7\n\n'])

    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize) 
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(fontsize) 
    ax.grid(True, linestyle='solid',linewidth=1)

#     for i in range(grid_size):
#         for j in range(grid_size):
#             plt.scatter(i + 0.5, j + 0.5,color='r',linewidths=4)

    xs = []    
    ys = []
    for i in range(14):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(13, 25):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='blue', linestyle='-', linewidth=4)
    
    xs = []    
    ys = []
    for i in range(28, 31):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='blue', linestyle='-', linewidth=4)
    
#     xs = []    
#     ys = []
#     for i in range(39, 45):
#         xs.append(points[i].xs[0]+0.5)
#         ys.append(points[i].xs[1]+0.5)
#     plt.plot(xs, ys, color='black', linestyle='-')
    
    xs = []    
    ys = []
    for i in range(30, 64):
        xs.append(points[i].xs[0]+0.5)
        ys.append(points[i].xs[1]+0.5)
    plt.plot(xs, ys, color='lightgray', linestyle='-.', linewidth=4)
    plt.xlabel("x", fontsize=fontsize)
    plt.ylabel("y", fontsize=fontsize)
    for window in windows:
        ax.add_patch(window)     
    plt.arrow(4.5, 2.5, 0.8, 0.0, color=section_color, width = 0.05)
    plt.arrow(5.5, 2.5, -0.8, 0.8, color=section_color, width = 0.05)
    plt.arrow(4.5, 3.5, 0.8, 0.0, color=section_color, width = 0.05)
    plt.arrow(5.5, 3.5, 0.8, -0.8, color=section_color, width = 0.05)
    
    
#     plt.arrow(4.5, 2.5, 0, 0.8, color='red', width = 0.05)
#     plt.arrow(4.5, 3.5, 0.8, -0.8, color='red', width = 0.05)
#     plt.arrow(5.5, 2.5, 0, 0.8, color='red', width = 0.05)
    
#     plt.arrow(6.5, 2.5, 0, 0.8, color='red', width = 0.05)
    plt.text(7.1, 2.2, '$q$', fontsize=30,color=window_color)
#     plt.text(3.3, 2.1, '$p_s$', fontsize=30)
#     plt.text(6.3, 3.6, '$p_e$', fontsize=30)
#     plt.text(3.1, 2.1, '$s_1$', fontsize=30,color="purple")
#     plt.text(3.0, 3.0, '$s_2$', fontsize=30,color="purple")
#     plt.text(6.0, 2.2, '$s_3$', fontsize=30,color="purple")
#     plt.text(6.3, 2.9, '$s_4$', fontsize=30,color="purple")
    plt.text(4.4, 2.1, '$e_1$', fontsize=30,color="red")
    plt.text(4.4, 2.8, '$e_2$', fontsize=30,color="red")
    plt.text(4.4, 3.6, '$e_3$', fontsize=30,color="red")
    plt.text(5.3, 2.8, '$e_4$', fontsize=30,color="red")
#     plt.text(2.3, 2.9, '$I_1$', fontsize=30,color="green")
#     plt.text(6.3, 0.9, '$I_2$', fontsize=30,color="green")
#     plt.text(7.3, 2.9, '$I_3$', fontsize=30,color="green")
#     plt.text(3.9, 3.5, '$I_1$', fontsize=30)
#     plt.text(5.9, 1.5, '$I_2$', fontsize=30)
#     plt.text(0.2, 0.1, 'start', fontsize=24)
#     plt.text(7.2, 7.7, 'end', fontsize=24)
#     plt.text(4.6, 2.2, '$p_i$', fontsize=30)
#     plt.text(4.6, 1.2, '$p_{i-1}$', fontsize=30)
#     plt.text(5.0, 3.6, '$p_j$', fontsize=30)
#     plt.text(6.0, 0.2, '$p_{j+1}$', fontsize=30)
    plt.scatter(3 + 0.5, 2 + 0.5,color=section_color,linewidths=4)
    plt.scatter(3 + 0.5, 3 + 0.5,color=section_color,linewidths=4)
    plt.scatter(6 + 0.5, 3 + 0.5,color=section_color,linewidths=4)
#     plt.scatter(6 + 0.5, 2 + 0.5,color='black',linewidths=4)
#     plt.scatter(4 + 0.5, 2 + 0.5,color='black',linewidths=4)
#     plt.scatter(5 + 0.5, 1 + 0.5,color='r',linewidths=4)
#     plt.scatter(5 + 0.5, 3 + 0.5,color='r',linewidths=4)
#     plt.scatter(6 + 0.5, 0 + 0.5,color='r',linewidths=4)
    plt.plot([1,1], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
    plt.plot([3,3], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
    plt.plot([5,5], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
    plt.plot([7,7], [0,8], color='gray', linestyle='-.',linewidth = 0.5)
    ax.arrow(7.5, 7.5, 0.01, 0, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
#     plt.title("Bit-sequence YXYXYX", fontsize=fontsize)
    ax.xaxis.set_label_coords(.5, -.06)
#     ax.arrow(7.5, 7.5, 0, 0.01, head_width=0.3, head_length=0.3, fc=curve_color, ec=curve_color, fill=False)
#     if is_save:
# #         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval_bit_distribution.eps',format='eps',bbox_inches = 'tight')
#         plt.savefig('../../../../应用/Overleaf/'+floder+'/figs/query_section_and_interval_bit_distribution.pdf',format='pdf',bbox_inches = 'tight')

grid_size = 8
bits_str = 'XXYYXY'[::-1]
bits_str = 'YXYXYX'[::-1]
w1 = patches.Rectangle((3, 2),4,2, linewidth=4,edgecolor=window_color,facecolor='none')
windows=[w1]
plot_z_curve_section_demo(grid_size, get_points(grid_size, bits_str), windows, bits_str[::-1])
# Out:
# YXYXYX
