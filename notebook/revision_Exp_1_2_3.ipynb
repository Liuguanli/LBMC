# %%
import matplotlib.pyplot as plt
# from mpl_toolkits.axisartist.axislines import SubplotZero
# import matplotlib.patches as patches
import random
import math
import copy
import time
import sys

import numpy as np
# import tensorflow as tf

import os

np.random.seed(1)

plt.rc('font',family='Times New Roman',size=20)
# plt.rc('lines', linewidth=3)

# labelsize=20
# fontsize=20
# legend_fontsize=20
# lw = 4
floder="VLDB2024"
random.seed(10)
bit_letters = ["A", "B", "C", "D", "E"]
factor_letters = ["a", "b", "c", "d", "e"]
logger_print = True
# value_letters = ["x", "y", "z"]
from time import perf_counter
plt.rcParams['hatch.linewidth'] = 2
# plt.rcParams['mathtext.default'] = 'DejaVu Sans'
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['mathtext.rm'] = 'serif'

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']  # 设置 Times 字体
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['mathtext.rm'] = 'serif'
plt.rcParams['mathtext.it'] = 'serif:italic'  # 设置数学斜体
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
markersize=10

colors = ['bisque', 'aquamarine', 'cornflowerblue']
colors = ['red', 'orange','orchid','limegreen', 'cornflowerblue', 'silver','brown']
markers=['o','^','s','1','x']
linewidth=3

# %%
# y_sampling=[151, 231, 364, 493, 599, 1423, 2747, 4096, 5411]
y_sampling=[2.6, 5.1, 8.9, 42.9, 115.7]
# y_sampling = [item * 1000 for item in y_sampling]
y_global = [0.01062] * 5
y_naive_global = [0.02348] * 5
y_local = [0.03523] * 5
y_naive_local=[1243, 1243, 1243, 1243, 1243]

plt.rcParams["figure.figsize"] = (7,3)
def plot_gloabl_cost_ratio(y_global, y_naive_global):
    x = np.array([0,1,2,3,4])
    # my_xticks = ['0.0001','0.0005','0.001','0.005','0.01']
    my_xticks = ['0.1','0.5','1','5','10']
    plt.xticks(x, my_xticks)

    plt.yticks([1e-3, 1e-2, 1e0, 1e2, 1e4], ['$10^{-3}$', '$10^{-2}$', '$10^0$', '$10^2$', '$10^4$'])
    plt.ylim(1e-3, 10000)
    
    plt.plot(x, y_global, label="GC", linewidth=linewidth, color=colors[0], marker=markers[0], markersize=markersize,markeredgewidth=1, markerfacecolor='none')
    plt.plot(x, y_naive_global, label="NGC", linewidth=linewidth, color=colors[1], marker=markers[1], markersize=markersize,markeredgewidth=1, markerfacecolor='none')
    plt.plot(x, y_local, label="LC", linewidth=linewidth, color=colors[2], marker=markers[2], markersize=markersize,markeredgewidth=1, markerfacecolor='none')
    plt.plot(x, y_naive_local, label="NLC", linewidth=linewidth, color=colors[3], marker=markers[3], markersize=markersize,markeredgewidth=1, markerfacecolor='none')
    plt.plot(x, y_sampling, label="SP", linewidth=linewidth, color=colors[4], marker=markers[4], markersize=markersize)

    for i, value in enumerate(y_sampling):
        plt.text(x[i], value+1.5, f'{value}', ha='center')

    
    ax = plt.subplot(111)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    plt.xlabel("Bit number on each dimension")
    # plt.xlabel(r'$\rho$')
    plt.xlabel(r'$\rho$ $(\times 10^{-3})$')
    # plt.yticks([1e-6, 1, 10000], ['$10^{-6}$', '$10^{0}$', '$10^4$'])
    plt.ylabel("Time (s)")
    plt.yscale('log')
    # plt.legend(ncol=5, labelspacing=0.0, columnspacing=1, handlelength=1, loc='best', fancybox=True, framealpha=0)
    plt.legend(ncol=5, labelspacing=0.0, columnspacing=0.8, handlelength=0.8, loc='upper center', 
           fancybox=True, framealpha=0, bbox_to_anchor=(0.4, 1.25))
    # ncol=2, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, framealpha=0

    plt.savefig('../figs/exp1/cost_sampling_rate_OSM.pdf',format='pdf',bbox_inches = 'tight') 
    plt.show()    
    
plot_gloabl_cost_ratio(y_global, y_naive_global)
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
y_sampling=[1.9, 3.9, 6.8, 29.4, 57.3]

y_global = [0.01157] * 5
y_naive_global = [0.02363] * 5
y_local = [0.03571] * 5
y_naive_local=[907, 907, 907, 907, 907]

plt.rcParams["figure.figsize"] = (7,3)
def plot_gloabl_cost_ratio(y_global, y_naive_global):
    x = np.array([0,1,2,3,4])
    my_xticks = ['0.1','0.5','1','5','10']
    plt.xticks(x, my_xticks)
    plt.yticks([1e-3, 1e-2, 1e0, 1e2, 1e4], ['$10^{-3}$', '$10^{-2}$', '$10^0$', '$10^2$', '$10^4$'])
    plt.ylim(1e-3, 10000)
    plt.plot(x, y_global, label="GC", linewidth=linewidth, color=colors[0], marker=markers[0], markersize=markersize,markeredgewidth=1, markerfacecolor='none')
    plt.plot(x, y_naive_global, label="NGC", linewidth=linewidth, color=colors[1], marker=markers[1], markersize=markersize,markeredgewidth=1, markerfacecolor='none')
    plt.plot(x, y_local, label="LC", linewidth=linewidth, color=colors[2], marker=markers[2], markersize=markersize,markeredgewidth=1, markerfacecolor='none')
    plt.plot(x, y_naive_local, label="NLC", linewidth=linewidth, color=colors[3], marker=markers[3], markersize=markersize,markeredgewidth=1, markerfacecolor='none')
    plt.plot(x, y_sampling, label="SP", linewidth=linewidth, color=colors[4], marker=markers[4], markersize=markersize)

    for i, value in enumerate(y_sampling):
        plt.text(x[i], value+1.5, f'{value}', ha='center')
    
    ax = plt.subplot(111)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    plt.xlabel("Bit number on each dimension")
    plt.xlabel(r'$\rho$ $(\times 10^{-3})$')
    # plt.yticks([1e-6, 1, 10000], ['$10^{-6}$', '$10^{0}$', '$10^4$'])
    plt.ylabel("Time (s)")
    plt.yscale('log')
    # plt.legend(ncol=5, labelspacing=0.0, columnspacing=1, handlelength=1, loc='best', fancybox=True, framealpha=0)
    plt.legend(ncol=5, labelspacing=0.0, columnspacing=0.8, handlelength=0.8, loc='upper center', 
           fancybox=True, frameon=False, bbox_to_anchor=(0.4, 1.25))
    # ncol=2, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, framealpha=0

    plt.savefig('../figs/exp1/cost_sampling_rate_SKEW.pdf',format='pdf',bbox_inches = 'tight') 
    plt.show()    
    
plot_gloabl_cost_ratio(y_global, y_naive_global)
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
# colors = ['silver','red', 'cornflowerblue', 'orange','orchid','limegreen','brown']
patterns = ['/', '\\', '|', '-', '+', 'x', 'o', 'O']
title_fontsize = 28
label_fontsize = 28
tick_fontsize = 28
annotation_fontsize = 18
markersize=12

# %%
# BMTree_SP = [1011, 1186, 1279, 1380, 1441]  # build cost
# LBMC = [5, 6, 6, 6, 7]

x_labels = ["16", "20", "24", "28", "32"]

labels = ['LBMC', 'CC', 'ZC', 'HC', 'MBTree-SP', 'QUILTS']

MBTreeSP = [1565,1489,1489,1489,1489]

all_methods = [[1062, 1068, 1044, 1044, 1044], 
 [4330, 4319, 4319, 4319, 4319], 
 [3485, 3466, 3466, 3466, 3466], 
 [3987, 3959, 3960, 3960, 3960], 
 [1565,1489,1489,1489,1489],
 [1106, 1161, 1161, 1147, 1257]]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Width of the bars

# Create an array with the position of each bar along the x-axis
# r1 = np.arange(len(x_labels))
# r2 = [x + width for x in r1]
# r3 = [x + width for x in r2]
# r4 = [x + width for x in r3]
# r5 = [x + width for x in r4]
# rs = [r1, r2, r3, r4, r5]

x = np.array([0,1,2,3,4])

for i in range(len(all_methods) - 1):
    plt.plot(x, all_methods[i], label=labels[i], linewidth=linewidth, color=colors[i], marker=markers[i], markersize=markersize)

ax.set_yscale('log')
ax.set_xlabel('$\ell$', fontsize=label_fontsize)
ax.set_ylabel('# Block accesses', fontsize=label_fontsize)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
# ax.set_xticks([r + int(len(rs) / 2)*width for r in range(len(all_methods[0]))])

plt.xticks(x, x_labels)

ax.set_xticklabels(x_labels, fontsize=tick_fontsize)

y_labels = [0, 1000, 2000, 3000, 4000, 5000]
y_labels = [1000, 10000]
ax.set_yticks(y_labels)

ax.legend(ncol=3, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, frameon=False)

# Adjust the layout to make room for the legend
plt.tight_layout()

plt.savefig('../figs/exp2/PG_tpc_vary_bits_OSM.pdf',format='pdf',bbox_inches = 'tight') 
plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
# BMTree_SP = [1011, 1186, 1279, 1380, 1441]  # build cost
# LBMC = [5, 6, 6, 6, 7]

x_labels = ["16", "20", "24", "28", "32"]

labels = ['LBMC','MBTree-SP']

all_methods = [[5, 6, 6, 6, 7], 
 [1011, 1186, 1279, 1380, 1441]]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Width of the bars

# Create an array with the position of each bar along the x-axis
# r1 = np.arange(len(x_labels))
# r2 = [x + width for x in r1]
# r3 = [x + width for x in r2]
# r4 = [x + width for x in r3]
# r5 = [x + width for x in r4]
# rs = [r1, r2, r3, r4, r5]

x = np.array([0,1,2,3,4])

# for i in range(len(all_methods)):
plt.plot(x, all_methods[0], label=labels[0], linewidth=linewidth, color=colors[0], marker=markers[0], markersize=markersize)
plt.plot(x, all_methods[1], label=labels[1], linewidth=linewidth, color=colors[4], marker=markers[4], markersize=markersize)

# ax.set_yscale('log')
ax.set_xlabel('$\ell$', fontsize=label_fontsize)
ax.set_ylabel('Time (s)', fontsize=label_fontsize)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
# ax.set_xticks([r + int(len(rs) / 2)*width for r in range(len(all_methods[0]))])

plt.xticks(x, x_labels)

ax.set_xticklabels(x_labels, fontsize=tick_fontsize)

y_labels = [10, 1000, 2000]
ax.set_yticks(y_labels)

ax.legend(ncol=2, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, frameon=False)

# Adjust the layout to make room for the legend
plt.tight_layout()

plt.savefig('../figs/exp2/PG_tpc_vary_bits_OSM_time.pdf',format='pdf',bbox_inches = 'tight') 
plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
labels = ['LBMC', 'CC', 'ZC', 'HC', 'QUILTS']

all_methods = [[179, 181, 180, 178, 178, 178],
 [201, 201, 201, 201, 201, 201], 
 [210, 210, 210, 210, 210, 210], 
 [209, 209, 209, 209, 209, 209], 
 [194, 194, 194, 194, 194, 194]]

fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

x = np.array([0,1,2,3,4,5])

for i in range(len(all_methods) - 1):
    plt.plot(x, all_methods[i], label=labels[i], linewidth=linewidth, color=colors[i], marker=markers[i], markersize=markersize)

# ax.set_yscale('log')
ax.set_xlabel('$\ell$', fontsize=label_fontsize)
ax.set_ylabel('Size (MB)', fontsize=label_fontsize)

x_labels = ["16", "24", "32", "48", "64"]
x_labels = ["16", "20", "24", "28", "32", "64"]

plt.xticks(x, x_labels)

ax.set_xticklabels(x_labels, fontsize=tick_fontsize)

y_labels = [175, 200, 225]
ax.set_yticks(y_labels)

ax.legend(ncol=4, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, frameon=False)

# Adjust the layout to make room for the legend
plt.tight_layout()

plt.savefig('../figs/exp3/hudi_tpc_vary_bits_NYC.pdf',format='pdf',bbox_inches = 'tight')    
plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

dataset_sizes = [16, 20, 24, 28, 32]

BMTree_GC = [887, 860, 860, 860, 860] 
BMTree_LC = [857, 839, 839, 839, 839] 
BMTree_SP = [874, 862, 869, 880, 873] 

all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(9.5, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], color=colors[i])

#     for rect in rects1:
#         height = rect.get_height()
#         ax.annotate(f'{height}',
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom', fontsize=annotation_fontsize, rotation=70)


# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$\ell$', fontsize=label_fontsize)
ax.set_ylabel('# Block accesses', fontsize=label_fontsize)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize)

# Add y-axis labels at specific positions
y_labels = [0, 200, 400, 600, 800, 1000]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

ax.legend(fontsize=tick_fontsize, fancybox=True, frameon=False)
ax.legend(ncol=7, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=2, fancybox=True, frameon=False)

plt.savefig('../figs/exp2/vary_bits_query.pdf',format='pdf',bbox_inches = 'tight') 


plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import json

# Load the data from the json files for both "swap any two" and "swap adjacent"
with open('../swap_any_two.json', 'r') as file:
    costs_any_two = json.load(file)

with open('../swap_adjacent.json', 'r') as file:
    costs_adjacent = json.load(file)

# Plot the costs on the same graph
plt.figure(figsize=(10, 4))
plt.plot(costs_any_two, label='Swap any two bits')
plt.plot(costs_adjacent, label='Swap adjacent bits')
plt.xlabel('$t$')
plt.ylabel('Cost')
# plt.title('Cost Reduction Over Iterations for Different Swap Strategies')
plt.legend(frameon=False)
plt.grid(True)

plt.savefig('../figs/compare_bit_swap.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import json

# Load the data from the json files for both "swap any two" and "swap adjacent"
with open('../swap_any_two.json', 'r') as file:
    costs_any_two = json.load(file)

with open('../swap_adjacent.json', 'r') as file:
    costs_adjacent = json.load(file)


max_value = max(max(costs_adjacent), max(costs_any_two))
min_value = min(min(costs_adjacent), min(costs_any_two))

costs_any_two = [cost / max_value for cost in costs_any_two]
costs_adjacent = [cost / max_value for cost in costs_adjacent]
costs_optimal = [min_value / max_value for cost in costs_adjacent]

# Plot the costs on the same graph
plt.figure(figsize=(10, 4))
plt.figure(figsize=(6, 4))
plt.plot(costs_adjacent, label='LBMC')
plt.plot(costs_any_two, label='Swap any two bits')
plt.plot(costs_optimal, label='Optimal', color="red", linestyle='--')
plt.xlabel('$t$')
plt.ylabel('Normalized Cost')
# plt.title('Cost Reduction Over Iterations for Different Swap Strategies')
plt.legend(loc='upper left', frameon=False, bbox_to_anchor=(0.04, 1.05))
plt.grid(True)

plt.savefig('../figs/compare_bit_swap.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
from time import perf_counter



# Font sizes
title_fontsize = 28
label_fontsize = 28
tick_fontsize = 28
annotation_fontsize = 18
markersize=12
# colors = ['bisque', 'aquamarine', 'cornflowerblue']
colors = ['silver','red', 'cornflowerblue', 'orange','orchid','limegreen','brown']
patterns = ['/', '\\', '|', '-', '+', 'x', 'o', 'O']
# markers=['o','^','s']
# colors = ['blue', 'green', 'red']
linewidth=4
plt.rcParams["figure.figsize"] = (6,2)

markers = [
    'o',  # circle marker
    '*',  # star marker
    's',  # square marker
    'v',  # triangle_down marker
    
    'D',  # hexagon2 marker
    'p',  # pentagon marker
    '>',  # triangle_right marker
    '1',  # tri_down marker
    'h',  # hexagon1 marker
'+',  # tri_right marker
    '+',  # plus marker
    'x',  # x marker
    'D',  # diamond marker
    'd',  # thin_diamond marker
    '|',  # vline marker
    '_'   # hline marker
]


# Dataset sizes and time saved scores
# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]


# BMTree_GC = [0.22, 0.76, 1.01, 1.87, 1.92, 4.79, 7.97, 29.2, 53.89, 98.43, 134]

# BMTree_LC = [0.18, 1.55, 2.73, 3.98, 5.37, 14.35, 24.08, 89.02, 196, 275, 411] 

# BMTree_SP = [262, 279,  287, 347, 377, 478, 584, 630, 701, 874, 1337] 

dataset_sizes = [1, 5, 10, 50, 100, 500, 1000, 1500, 2000]


BMTree_GC = [0.22, 0.76, 1.01,  4.79, 7.97, 29.2, 53.89, 98.43, 134]

BMTree_LC = [0.18, 1.55, 2.73,  14.35, 24.08, 89.02, 196, 275, 411] 

BMTree_SP = [262, 279,  287,  478, 584, 630, 701, 874, 1337] 

for i in range(9):
    print(BMTree_SP[i] - BMTree_LC[i])




all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP,
]



labels = ['BMTree-GC', 'BMTree-LC', 'BMTree-SP']

# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Font sizes
title_fontsize = 26
label_fontsize = 26
tick_fontsize = 26
annotation_fontsize = 16

for i in range(len(all_methods)):

    line1, = ax.plot(range(len(dataset_sizes)), all_methods[i], linewidth=linewidth, markersize=markersize,
        color=colors[i], marker=markers[i], label=labels[i],markeredgewidth=1)

# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize + 12)
ax.set_ylabel('Reward calculation \n time (s)', fontsize=label_fontsize + 12)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=title_fontsize)
# ax.set_xticklabels(fontsize=tick_fontsize)


# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize + 6)

# Add y-axis labels at specific positions
y_labels = [1, 10, 100, 1000, 10000, 100000]
ax.set_yticks(y_labels)
# ax.set_xticks(dataset_sizes)
ax.set_xticks(range(len(dataset_sizes)))
ax.set_xticklabels(dataset_sizes)
# ax.set_xticklabels([f'$10^{int(np.log10(size))}$' for size in dataset_sizes], fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize + 6)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)
# ax.legend(fontsize=tick_fontsize, fancybox=True, framealpha=0, ncol=3)
ax.legend(ncol=2, labelspacing=0.0, fontsize=tick_fontsize+6, columnspacing=1, borderpad=0, handlelength=2, fancybox=True, frameon=False)

plt.savefig('../figs/exp2/vary_mix_query_num_time_revision.pdf',format='pdf',bbox_inches = 'tight') 
plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp
# 261.82
# 277.45
# 284.27
# 463.65
# 559.92
# 540.98
# 505
# 599
# 926

# %%
# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC = [1240, 1235, 1195, 1125, 1064, 1209, 1233, 1232, 1200, 1115, 860] # Method B
# BMTree_LC = [965, 1017, 1022, 935, 903, 856, 841, 840, 839, 840, 839] # Method B
# BMTree_SP = [1788, 1076, 988, 1064, 1214, 1164, 1153, 1456, 1395, 1065, 871] # Method A

dataset_sizes = [1, 5, 10, 50, 100, 500, 1000, 1500, 2000]

BMTree_GC = [1240, 1235, 1195, 1209, 1233, 1232, 1200, 1115, 860] # Method B
BMTree_LC = [965, 1017, 1022,  856, 841, 840, 839, 840, 839] # Method B
BMTree_SP = [1788, 1076, 988,  1164, 1153, 1456, 1395, 1065, 871] # Method A


all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], color=colors[i])
    
# Add a horizontal line with a label 'ZC'
# ax.axhline(y=2115, color='orange', linestyle='--', label="CC")
# ax.axhline(y=1974, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=1983, color='limegreen', linestyle='-.', label="HC")


# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize + 12)
ax.set_ylabel('# Block accesses', fontsize=label_fontsize + 12)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize + 6)

# Add y-axis labels at specific positions
y_labels = [0, 1000, 2000, 2200]
# y_labels = [0, 1000, 2000]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

ax.legend(fontsize=tick_fontsize, fancybox=True, frameon=False)
ax.legend(ncol=2, labelspacing=0.0, fontsize=tick_fontsize+6, columnspacing=0.3, borderpad=0.0, handlelength=1.2, fancybox=True, frameon=False)

plt.savefig('../figs/exp2/vary_incremental_query_num_query_revision.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

# dataset_sizes = [100, 500, 1000, 1500, 2000]

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC = [1455, 1436, 1354, 1287, 1233, 1336, 1417, 1358, 1321, 1252, 960] # Method B
# BMTree_LC = [1048, 1148, 1173, 1014, 987, 929, 921, 916, 914, 916, 914] # Method B
# BMTree_SP = [1736, 1179, 1104, 1167, 1375, 1342, 1290, 1471, 1447, 1155, 927] # Method A

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC = [1455, 1436, 1354, 1287, 1233, 1336, 1417, 1358, 1321, 1252, 960] # Method B
# BMTree_LC = [1048, 1148, 1173, 1014, 987, 929, 921, 916, 914, 916, 914] # Method B
# BMTree_SP = [1736, 1179, 1104, 1167, 1375, 1342, 1290, 1471, 1447, 1155, 927] # Method A


dataset_sizes = [1, 5, 10, 50, 100, 500, 1000, 1500, 2000]

BMTree_GC = [1455, 1436, 1354,  1336, 1417, 1358, 1321, 1252, 960] # Method B
BMTree_LC = [1048, 1148, 1173,  929, 921, 916, 914, 916, 914] # Method B
BMTree_SP = [1736, 1179, 1104, 1342, 1290, 1471, 1447, 1155, 927] # Method A


all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], color=colors[i])

    # for rect in rects1:
    #     height = rect.get_height()
    #     ax.annotate(f'{height}',
    #                 xy=(rect.get_x() + rect.get_width() / 2, height),
    #                 xytext=(0, 3),  # 3 points vertical offset
    #                 textcoords="offset points",
    #                 ha='center', va='bottom', fontsize=annotation_fontsize, rotation=70)

# ax.axhline(y=2138, color='orange', linestyle='--', label="CC")
# ax.axhline(y=1974, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=1981, color='limegreen', linestyle='-.', label="HC")


# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize + 2)
ax.set_ylabel('# Block accesses', fontsize=label_fontsize + 6)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize)

# Add y-axis labels at specific positions
y_labels = [0, 1000, 2000,2500]
y_labels = [0, 1000, 2000]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

ax.legend(fontsize=tick_fontsize, fancybox=True, frameon=False)
ax.legend(ncol=6, labelspacing=0.0, columnspacing=0.3, borderpad=0.0, handlelength=1.2, fancybox=True, frameon=False)

plt.savefig('../figs/exp2/vary_mix_query_num_query_revision_25p.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

# dataset_sizes = [100, 500, 1000, 1500, 2000]

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC = [1597, 1597, 1462, 1419, 1402, 1453, 1587, 1491, 1434, 1349, 1085] # Method B
# BMTree_LC = [1180, 1262, 1288, 1104, 1071, 1029, 1017, 1015, 1013, 1015, 1013] # Method B
# BMTree_SP = [1770, 1307, 1234, 1270, 1466, 1461, 1358, 1611, 1602, 1271, 1179] # Method A


dataset_sizes = [1, 5, 10,  50, 100, 500, 1000, 1500, 2000]

BMTree_GC = [1597, 1597, 1462, 1453, 1587, 1491, 1434, 1349, 1085] # Method B
BMTree_LC = [1180, 1262, 1288,  1029, 1017, 1015, 1013, 1015, 1013] # Method B
BMTree_SP = [1770, 1307, 1234,  1461, 1358, 1611, 1602, 1271, 1179] # Method A



all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], color=colors[i])

    # for rect in rects1:
    #     height = rect.get_height()
    #     ax.annotate(f'{height}',
    #                 xy=(rect.get_x() + rect.get_width() / 2, height),
    #                 xytext=(0, 3),  # 3 points vertical offset
    #                 textcoords="offset points",
    #                 ha='center', va='bottom', fontsize=annotation_fontsize, rotation=70)

# ax.axhline(y=2209, color='orange', linestyle='--', label="CC")
# ax.axhline(y=2079, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=2053, color='limegreen', linestyle='-.', label="HC")

# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize+ 12)
ax.set_ylabel('# Block accesses', fontsize=label_fontsize + 12)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize + 6)

# Add y-axis labels at specific positions
y_labels = [0, 1000, 2000, 2200]
# y_labels = [0, 1000, 2000]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

ax.legend(fontsize=tick_fontsize, fancybox=True, frameon=False)
ax.legend(ncol=2, labelspacing=0.0, columnspacing=0.3, fontsize=tick_fontsize+6, borderpad=0.0, handlelength=1.2, fancybox=True, frameon=False)

plt.savefig('../figs/exp2/vary_mix_query_num_query_revision_50p.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

# dataset_sizes = [100, 500, 1000, 1500, 2000]

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC = [1722, 1729, 1565, 1513, 1567, 1577, 1765, 1614, 1542, 1437, 1233] # Method B
# BMTree_LC = [1339, 1413, 1423, 1235, 1207, 1162, 1155, 1149, 1147, 1148, 1146] # Method B
# BMTree_SP = [1894, 1462, 1403, 1390, 1572, 1569, 1441, 1690, 1621, 1390, 1264] # Method A

dataset_sizes = [1, 5, 10, 50, 100, 500, 1000, 1500, 2000]

BMTree_GC = [1722, 1729, 1565,  1577, 1765, 1614, 1542, 1437, 1233] # Method B
BMTree_LC = [1339, 1413, 1423, 1162, 1155, 1149, 1147, 1148, 1146] # Method B
BMTree_SP = [1894, 1462, 1403,  1569, 1441, 1690, 1621, 1390, 1264] # Method A




all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], color=colors[i])

    # for rect in rects1:
    #     height = rect.get_height()
    #     ax.annotate(f'{height}',
    #                 xy=(rect.get_x() + rect.get_width() / 2, height),
    #                 xytext=(0, 3),  # 3 points vertical offset
    #                 textcoords="offset points",
    #                 ha='center', va='bottom', fontsize=annotation_fontsize, rotation=70)

# ax.axhline(y=2194, color='orange', linestyle='--', label="CC")
# ax.axhline(y=2079, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=2053, color='limegreen', linestyle='-.', label="HC")

# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize+ 12)
ax.set_ylabel('# Block accesses', fontsize=label_fontsize + 12)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize + 7)

# Add y-axis labels at specific positions
y_labels = [0, 1000, 2000,2500]
y_labels = [0, 1000, 2000]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

# ax.legend(fontsize=tick_fontsize, fancybox=True, framealpha=0)
# ax.legend(ncol=2, labelspacing=0.0, columnspacing=0.3, fontsize=tick_fontsize, borderpad=0.0, handlelength=1.2, fancybox=True, framealpha=0)

plt.savefig('../figs/exp2/vary_mix_query_num_query_revision_75p.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

# dataset_sizes = [100, 500, 1000, 1500, 2000]

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC = [1884, 1825, 1668, 1618, 1669, 1663, 1830, 1691, 1625, 1499, 1293] # Method B
# BMTree_LC = [1421, 1447, 1458, 1285, 1267, 1202, 1192, 1182, 1180, 1182, 1179] # Method B
# BMTree_SP = [1943, 1550, 1477, 1474, 1646, 1671, 1521, 1763, 1643, 1436, 1303] # Method A

dataset_sizes = [1, 5, 10,  50, 100, 500, 1000, 1500, 2000]

BMTree_GC = [1884, 1825, 1668,  1663, 1830, 1691, 1625, 1499, 1293] # Method B
BMTree_LC = [1421, 1447, 1458,  1202, 1192, 1182, 1180, 1182, 1179] # Method B
BMTree_SP = [1943, 1550, 1477,  1671, 1521, 1763, 1643, 1436, 1303] # Method A




all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], color=colors[i])

    # for rect in rects1:
    #     height = rect.get_height()
    #     ax.annotate(f'{height}',
    #                 xy=(rect.get_x() + rect.get_width() / 2, height),
    #                 xytext=(0, 3),  # 3 points vertical offset
    #                 textcoords="offset points",
    #                 ha='center', va='bottom', fontsize=annotation_fontsize, rotation=70)

# ax.axhline(y=2185, color='orange', linestyle='--', label="CC")
# ax.axhline(y=2099, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=2074, color='limegreen', linestyle='-.', label="HC")

# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize + 12)
ax.set_ylabel('# Block accesses', fontsize=label_fontsize + 12)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize + 7)

# Add y-axis labels at specific positions
y_labels = [0, 1000, 2000,2500]
y_labels = [0, 1000, 2000]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

# ax.legend(fontsize=tick_fontsize, fancybox=True, framealpha=0)
# ax.legend(ncol=6, labelspacing=0.0, columnspacing=0.3, fontsize=tick_fontsize-1, borderpad=0.0, handlelength=1.2, fancybox=True, framealpha=0)

plt.savefig('../figs/exp2/vary_mix_query_num_query_revision_100p.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

# dataset_sizes = [100, 500, 1000, 1500, 2000]

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC = [158, 158, 152, 142, 137, 155, 161, 157, 152, 142, 111] # Method B
# BMTree_GC_1 = [355, 322, 307, 292, 283, 307, 328, 320, 309, 287, 223] # Method B
# BMTree_LC = [123, 131, 131, 119, 114, 110, 109, 107, 106, 109, 108] # Method B
# BMTree_LC_1 = [253, 264, 270, 240, 238, 223, 217, 214, 216, 218, 215] # Method B
# BMTree_SP = [221, 140, 126, 135, 155, 149, 148, 187, 177, 133, 138] # Method B
# BMTree_SP_1 = [440, 282, 253, 276, 316, 301, 300, 373, 371, 266, 286] # Method A

dataset_sizes = [1, 5, 10, 50, 100, 500, 1000, 1500, 2000]

BMTree_GC = [158, 158, 152,  155, 161, 157, 152, 142, 111] # Method B
BMTree_GC_1 = [355, 322, 307, 307, 328, 320, 309, 287, 223] # Method B
BMTree_LC = [123, 131, 131,  110, 109, 107, 106, 109, 108] # Method B
BMTree_LC_1 = [253, 264, 270, 223, 217, 214, 216, 218, 215] # Method B
BMTree_SP = [221, 140, 126,  149, 148, 187, 177, 133, 138] # Method B
BMTree_SP_1 = [440, 282, 253,  301, 300, 373, 371, 266, 286] # Method A

BMTree_GC = [BMTree_GC[i] + BMTree_GC_1[i] for i in range(len(BMTree_GC))]
BMTree_LC = [BMTree_LC[i] + BMTree_LC_1[i] for i in range(len(BMTree_LC))]
BMTree_SP = [BMTree_SP[i] + BMTree_SP_1[i] for i in range(len(BMTree_SP))]



all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], color=colors[i])

# ax.axhline(y=1075, color='orange', linestyle='--', label="CC")
# ax.axhline(y=848, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=831, color='limegreen', linestyle='-.', label="HC")

# ax.axhline(y=2000, color='r', linestyle='--', label="Random")

# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize)
ax.set_ylabel('Average query time (ms)', fontsize=label_fontsize)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize)

# Add y-axis labels at specific positions
y_labels = [0,200,400,600, 800, 1000, 1200]
y_labels = [0,200,400,600, 800]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

ax.legend(fontsize=tick_fontsize, fancybox=True, frameon=False)
# ax.legend(ncol=7, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=2, fancybox=True, framealpha=0)
ax.legend(ncol=6, labelspacing=0.0, columnspacing=0.3, borderpad=0.0, handlelength=1.2, fancybox=True, frameon=False)

plt.savefig('../figs/exp2/vary_mix_query_num_query_revision_redis.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

# dataset_sizes = [100, 500, 1000, 1500, 2000]

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC = [186, 188, 174, 164, 157, 174, 182, 170, 175, 163, 124] # Method B
# BMTree_GC_1 = [383, 380, 349, 335, 318, 358, 366, 355, 355, 322, 255] # Method B
# BMTree_LC = [135, 145, 150, 130, 126, 119, 119, 117, 116, 118, 117] # Method B
# BMTree_LC_1 = [266, 300, 306, 286, 254, 241, 237, 237, 234, 234, 241] # Method B
# BMTree_SP = [223, 154, 144, 148, 178, 170, 172, 189, 187, 148, 148] # Method B
# BMTree_SP_1 = [450, 304, 293, 301, 359, 343, 329, 378, 386, 314, 303] # Method A


dataset_sizes = [1, 5, 10,  50, 100, 500, 1000, 1500, 2000]

BMTree_GC = [186, 188, 174, 174, 182, 170, 175, 163, 124] # Method B
BMTree_GC_1 = [383, 380, 349, 358, 366, 355, 355, 322, 255] # Method B
BMTree_LC = [135, 145, 150,  119, 119, 117, 116, 118, 117] # Method B
BMTree_LC_1 = [266, 300, 306,  241, 237, 237, 234, 234, 241] # Method B
BMTree_SP = [223, 154, 144,  170, 172, 189, 187, 148, 148] # Method B
BMTree_SP_1 = [450, 304, 293,  343, 329, 378, 386, 314, 303] # Method A

BMTree_GC = [BMTree_GC[i] + BMTree_GC_1[i] for i in range(len(BMTree_GC))]
BMTree_LC = [BMTree_LC[i] + BMTree_LC_1[i] for i in range(len(BMTree_LC))]
BMTree_SP = [BMTree_SP[i] + BMTree_SP_1[i] for i in range(len(BMTree_SP))]



all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], color=colors[i])

# ax.axhline(y=1035, color='orange', linestyle='--', label="CC")
# ax.axhline(y=859, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=843, color='limegreen', linestyle='-.', label="HC")

# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize)
ax.set_ylabel('Average query time (ms)', fontsize=label_fontsize)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize)

# Add y-axis labels at specific positions
y_labels = [0,200,400,600, 800, 1000,1200]
y_labels = [0,200,400,600, 800]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

ax.legend(fontsize=tick_fontsize, fancybox=True, frameon=False)
# ax.legend(ncol=7, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=2, fancybox=True, framealpha=0)
ax.legend(ncol=6, labelspacing=0.0, columnspacing=0.3, borderpad=0.0, handlelength=1.2, fancybox=True, frameon=False)

plt.savefig('../figs/exp2/vary_mix_query_num_query_revision_redis25.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

# dataset_sizes = [100, 500, 1000, 1500, 2000]

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC =   [204, 205, 187, 183, 181, 185, 204, 190, 185, 175, 140] 
# BMTree_GC_1 = [417, 415, 388, 389, 376, 375, 419, 397, 383, 348, 283] 
# BMTree_LC =   [160, 161, 162, 139, 137, 132, 131, 128, 129, 130, 129] 
# BMTree_LC_1 = [299, 321, 339, 288, 272, 263, 264, 254, 261, 260, 257] 
# BMTree_SP =   [226, 169, 160, 163, 186, 185, 172, 231, 215, 164, 161] 
# BMTree_SP_1 = [460, 341, 318, 328, 385, 383, 354, 428, 421, 327, 337] 

dataset_sizes = [1, 5, 10,  50, 100, 500, 1000, 1500, 2000]

BMTree_GC =   [204, 205, 187,  185, 204, 190, 185, 175, 140] 
BMTree_GC_1 = [417, 415, 388,  375, 419, 397, 383, 348, 283] 
BMTree_LC =   [160, 161, 162,  132, 131, 128, 129, 130, 129] 
BMTree_LC_1 = [299, 321, 339,  263, 264, 254, 261, 260, 257] 
BMTree_SP =   [226, 169, 160,  185, 172, 231, 215, 164, 161] 
BMTree_SP_1 = [460, 341, 318,  383, 354, 428, 421, 327, 337] 

BMTree_GC = [BMTree_GC[i] + BMTree_GC_1[i] for i in range(len(BMTree_GC))]
BMTree_LC = [BMTree_LC[i] + BMTree_LC_1[i] for i in range(len(BMTree_LC))]
BMTree_SP = [BMTree_SP[i] + BMTree_SP_1[i] for i in range(len(BMTree_SP))]



all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], alpha=bar_alpha, color=colors[i])


# ax.axhline(y=1048, color='orange', linestyle='--', label="CC")
# ax.axhline(y=827, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=823, color='limegreen', linestyle='-.', label="HC")


# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize)
ax.set_ylabel('Average query time (ms)', fontsize=label_fontsize)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize)

# Add y-axis labels at specific positions
y_labels = [0,200,400,600, 800, 1000,1200]
y_labels = [0,200,400,600, 800]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

ax.legend(fontsize=tick_fontsize, fancybox=True, framealpha=0)
# ax.legend(ncol=7, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=2, fancybox=True, framealpha=0)
ax.legend(ncol=6, labelspacing=0.0, columnspacing=0.3, borderpad=0.0, handlelength=1.2, fancybox=True, framealpha=0)

plt.savefig('../figs/exp2/vary_mix_query_num_query_revision_redis50.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

# dataset_sizes = [100, 500, 1000, 1500, 2000]

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC =   [220, 223, 202, 199, 197, 199, 224, 207, 207, 185, 157] 
# BMTree_GC_1 = [467, 462, 405, 402, 403, 416, 460, 417, 416, 350, 332] 
# BMTree_LC =   [172, 182, 180, 157, 155, 147, 148, 145, 148, 147, 147] 
# BMTree_LC_1 = [346, 376, 362, 328, 317, 302, 299, 298, 296, 305, 291] 
# BMTree_SP =   [241, 188, 182, 185, 202, 203, 183, 217, 208, 178, 189] 
# BMTree_SP_1 = [499, 375, 360, 358, 407, 399, 366, 441, 428, 385, 401] 

dataset_sizes = [1, 5, 10,  50, 100, 500, 1000, 1500, 2000]

BMTree_GC =   [220, 223, 202,  199, 224, 207, 207, 185, 157] 
BMTree_GC_1 = [467, 462, 405,  416, 460, 417, 416, 350, 332] 
BMTree_LC =   [172, 182, 180,  147, 148, 145, 148, 147, 147] 
BMTree_LC_1 = [346, 376, 362,  302, 299, 298, 296, 305, 291] 
BMTree_SP =   [241, 188, 182,  203, 183, 217, 208, 178, 189] 
BMTree_SP_1 = [499, 375, 360,  399, 366, 441, 428, 385, 401] 

BMTree_GC = [BMTree_GC[i] + BMTree_GC_1[i] for i in range(len(BMTree_GC))]
BMTree_LC = [BMTree_LC[i] + BMTree_LC_1[i] for i in range(len(BMTree_LC))]
BMTree_SP = [BMTree_SP[i] + BMTree_SP_1[i] for i in range(len(BMTree_SP))]



all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], alpha=bar_alpha, color=colors[i])

# ax.axhline(y=1029, color='orange', linestyle='--', label="CC")
# ax.axhline(y=839, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=828, color='limegreen', linestyle='-.', label="HC")


# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize)
ax.set_ylabel('Average query time (ms)', fontsize=label_fontsize)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize)

# Add y-axis labels at specific positions
y_labels = [0,200,400,600, 800,1000,1200]
y_labels = [0,200,400,600, 800]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

ax.legend(fontsize=tick_fontsize, fancybox=True, framealpha=0)
# ax.legend(ncol=7, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=2, fancybox=True, framealpha=0)
ax.legend(ncol=6, labelspacing=0.0, columnspacing=0.3, borderpad=0.0, handlelength=1.2, fancybox=True, framealpha=0)

plt.savefig('../figs/exp2/vary_mix_query_num_query_revision_redis75.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

# Dataset sizes and time saved scores
# dataset_sizes = [1, 10, 100, 1000, 10000]

# dataset_sizes = [100, 500, 1000, 1500, 2000]

# dataset_sizes = [1, 5, 10, 15, 20, 50, 100, 500, 1000, 1500, 2000]

# BMTree_GC =   [245, 232, 213, 205, 209, 210, 229, 216, 210, 191, 165] 
# BMTree_GC_1 = [499, 485, 434, 421, 438, 435, 475, 433, 419, 392, 334] 
# BMTree_LC =   [183, 183, 186, 164, 162, 156, 152, 151, 149, 152, 149] 
# BMTree_LC_1 = [378, 386, 372, 346, 336, 309, 302, 310, 310, 301, 300] 
# BMTree_SP =   [251, 199, 187, 191, 207, 212, 193, 226, 211, 183, 205] 
# BMTree_SP_1 = [513, 404, 383, 390, 440, 432, 408, 472, 426, 373, 417] 

dataset_sizes = [1, 5, 10,  50, 100, 500, 1000, 1500, 2000]

BMTree_GC =   [245, 232, 213,  210, 229, 216, 210, 191, 165] 
BMTree_GC_1 = [499, 485, 434,  435, 475, 433, 419, 392, 334] 
BMTree_LC =   [183, 183, 186,  156, 152, 151, 149, 152, 149] 
BMTree_LC_1 = [378, 386, 372,  309, 302, 310, 310, 301, 300] 
BMTree_SP =   [251, 199, 187,  212, 193, 226, 211, 183, 205] 
BMTree_SP_1 = [513, 404, 383,  432, 408, 472, 426, 373, 417] 

BMTree_GC = [BMTree_GC[i] + BMTree_GC_1[i] for i in range(len(BMTree_GC))]
BMTree_LC = [BMTree_LC[i] + BMTree_LC_1[i] for i in range(len(BMTree_LC))]
BMTree_SP = [BMTree_SP[i] + BMTree_SP_1[i] for i in range(len(BMTree_SP))]



all_methods = [
    BMTree_GC,
    BMTree_LC,
    BMTree_SP
]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(12, 5))

# Width of the bars
width = 0.25
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
    
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(dataset_sizes))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]

rs = [r1, r2, r3]


for i in range(len(all_methods)):
# Plot time saved comparison chart with semi-transparent bars
#     rects1 = ax.bar(rs[i], all_methods[i], width, label=labels[i], alpha=bar_alpha, color=colors[i])
    rects1 = ax.bar(rs[i], all_methods[i], width,hatch=patterns[i], label=labels[i], alpha=bar_alpha, color=colors[i])

# ax.axhline(y=1082, color='orange', linestyle='--', label="CC")
# ax.axhline(y=881, color='orchid', linestyle=':', label="ZC")
# ax.axhline(y=868, color='limegreen', linestyle='-.', label="HC")

# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlabel('$n$', fontsize=label_fontsize)
ax.set_ylabel('Average query time (ms)', fontsize=label_fontsize)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
ax.set_xticks([r + width for r in range(len(dataset_sizes))])
# ax.set_xticklabels(dataset_sizes, fontsize=tick_fontsize)
ax.set_xticklabels([str(size) for size in dataset_sizes], fontsize=tick_fontsize)

# Set tick font sizes
ax.tick_params(axis='both', which='major', labelsize=tick_fontsize)

# Add y-axis labels at specific positions
y_labels = [0,200,400,600, 800, 1000, 1200]
y_labels = [0,200,400,600, 800]
ax.set_yticks(y_labels)
# ax.set_yticklabels([f'$10^{int(np.log10(size))}$' for size in y_labels], fontsize=tick_fontsize)

ax.legend(fontsize=tick_fontsize, fancybox=True, framealpha=0)
# ax.legend(ncol=7, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=2, fancybox=True, framealpha=0)
# ax.legend(ncol=5, labelspacing=0.0, columnspacing=0.5, borderpad=0.2, handlelength=1.5, fancybox=True, framealpha=0)
ax.legend(ncol=6, labelspacing=0.0, columnspacing=0.3, borderpad=0.0, handlelength=1.2, fancybox=True, framealpha=0)

plt.savefig('../figs/exp2/vary_mix_query_num_query_revision_redis100.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
# import psycopg2

# conn = psycopg2.connect("dbname=postgres user=postgres password={} host=localhost port=5432".format(args.db_password))
# cur = conn.cursor()

# cur.execute("DROP TABLE IF EXISTS location;")
# cur.execute("DROP TABLE IF EXISTS values;")
# cur.execute("DROP TABLE IF EXISTS location_value;")
# cur.execute('SET enable_bitmapscan TO off;')

# cur.execute('SELECT pg_stat_statements_reset();')

# dim_names = [f'dim{i + 1}' for i in range(data_dim)]
# sqlstr_dim_name = ' int, '.join(dim_names) + ' int'
# cur.execute("CREATE TABLE location_value (id integer, {}, sfcvalue bigint);".format(sqlstr_dim_name))
# print('--create table--')

# dim_id_names = tuple(['id'] + dim_names + ['sfcvalue'])
# with open('spectral_10000.csv', 'r') as f:
#     cur.copy_from(f, 'location_value', sep=',', columns=dim_id_names)

# print('--finished--')

# cur.execute('create index on location_value USING btree (sfcvalue) WITH (fillfactor=100);')
# cur.execute('SELECT indexname FROM pg_indexes WHERE schemaname = \'public\';')
# index_name = cur.fetchall()[0][0]
# cur.execute("cluster location_value using {};".format(index_name))

# print('--build finished--')

# print('--start window query--')
# print('training query: {}'.format(args.train_query))
# print('testing query: {}'.format(args.query))
# print('action_depth: {}'.format(args.action_depth))


# number_of_records = 0
# start_time = time.time()
# for i, query in enumerate(queries):
#     filter = ' '.join(['and (dim{} between {} and {})'.format(dim + 1, query[i][dim][0], query[i][dim][1]) for dim in range(2)])
#     cur.execute(
#         "select * from location_value where \
#         (sfcvalue between {} and {}) {};".format(
#             value[0], value[1], filter))
#     result = cur.fetchall()

#     # Get the number of records
#     number_of_records += len(result)

# end_time = time.time()
# time_usage = end_time - start_time
# print('finish running, time usage: {} ms'.format(time_usage * 1000 / len(queries_box)))

# cur.execute(
#     'select mean_exec_time, shared_blks_hit, shared_blks_read, local_blks_hit, local_blks_read, temp_blks_read from pg_stat_statements where query like \'select * from location_value where%\';')
# # cur.execute(
# #     'select * from pg_stat_statements where query like \'select * from location_value where%\';')
# result = cur.fetchall()

# # print(result)

# avg_block_hit = sum([row[1] for row in result]) / len(queries_box)
# avg_block_read= sum([row[2] for row in result]) / len(queries_box)

# print('avg block hit: {}, avg block read:{}, avg block access:{}'.format(avg_block_hit, avg_block_read, avg_block_hit + avg_block_read))
# print('all_result_num: {}'.format(number_of_records))
# # mean_exec_time, shared_blks_hit, shared_blks_read, local_blks_hit, local_blks_read, temp_blks_read

# conn.commit()
# cur.close()
# conn.close()

# %%
# import redis
# from time import time
# import random

# r = redis.Redis(host='localhost', port=6379, db=0)

# def insert_data(data):
#     r.delete('myzset')
    
#     for score, value in data:
#         r.zadd('myzset', {value: score})

# def range_query(min_score, max_score):
#     return r.zrangebyscore('myzset', min_score, max_score)


# # def calculate_z_value(point)

# data = [i for i in range(1, 1000001)]

# ordered_data = [(i, f"item{i}:field") for i in data]
# random.shuffle(data)

# random_data = [(i, f"item{i}:field") for i in data]

# insert_data(ordered_data)
# start_time = time()
# range_query(1, 10000)
# # print("Ordered Data Query Results:", range_query(300, 700))
# ordered_query_time = time() - start_time

# print(f"Ordered Data Query Time: {ordered_query_time:.4f}s")


# insert_data(random_data)
# start_time = time()
# range_query(10001, 20000)
# # print("Random Data Query Results:", range_query(300, 700))
# random_query_time = time() - start_time


# print(f"Random Data Query Time: {random_query_time:.4f}s")
# Out:
# Ordered Data Query Time: 0.0061s
# Random Data Query Time: 0.0065s

# %%
# # import matplotlib.pyplot as plt
# # import json

# # def read_json(json_file):
# #     # Load data from JSON file
# #     with open(json_file, 'r') as file:
# #         data = json.load(file)
# #     return data

# # def plot_rectangles(data):
# #     # Create a single figure and subplot
# #     fig, ax = plt.subplots(1, 1, figsize=(10, 8), constrained_layout=True)
    
# #     colors = ['red', 'green', 'blue', 'orange', 'purple']  # Colors for different queries
# #     color_index = 0
    
# #     for query, coordinates_list in data.items():
# #         index = 0
# #         for coordinates in coordinates_list:
# #             # Assuming coordinates are in the form [x1, y1, x2, y2]
# #             x1, y1, x2, y2 = coordinates[1], coordinates[0], coordinates[3], coordinates[2]
# #             rect = plt.Rectangle((min(x1, x2), min(y1, y2)), abs(x2 - x1), abs(y2 - y1),
# #                                  linewidth=1, edgecolor=colors[color_index % len(colors)], facecolor='none', label=query if index == 0 else "")
# #             ax.add_patch(rect)
# #             index += 1
# #         color_index += 1

# #     # Hide axes
# #     # ax.set_axis_off()
    
# #     ax.set_xticks([]) 
# #     ax.set_yticks([]) 
# #     ax.set_aspect('equal', adjustable='box')  # Maintain aspect ratio
# #     ax.autoscale_view()  # Auto-scale view to include all rectangles
# #     ax.legend(loc='upper left', bbox_to_anchor=(1.05, 1))

# #     plt.savefig('../../../../应用/Overleaf/VLDB2024 (revision)/figs/nyc_query.pdf',format='pdf',bbox_inches = 'tight') 
# #     plt.savefig('../../../../应用/Overleaf/VLDB2024_revision_CoverLetter/nyc_query.pdf',format='pdf',bbox_inches = 'tight') 

# #     plt.show()

# # # Example usage
# # json_file = '../hudi/result/nyc_query.json'  # Update path as necessary
# # data = read_json(json_file)
# # plot_rectangles(data)
# import json

# def read_json(json_file):
#     # Load data from JSON file
#     with open(json_file, 'r') as file:
#         data = json.load(file)
#     return data

# def plot_rectangles(data):
#     # Determine the number of queries and create a figure with that many subplots
#     num_queries = len(data)
#     fig, axes = plt.subplots(1, num_queries, figsize=(num_queries * 2, 2), constrained_layout=True)
    
#     colors = ['red', 'green', 'blue', 'orange', 'purple']  # Colors for different queries
#     queries = list(data.keys())  # Convert keys to a list for indexing
#     i=1
#     for ax, (query, coordinates_list) in zip(axes.flatten(), data.items()):
#         for coordinates in coordinates_list:
#             # Assuming coordinates are in the form [x1, y1, x2, y2]
#             if i == 4:
#                 x1, y1, x2, y2 = coordinates[1], coordinates[0], coordinates[3], coordinates[2]
#                 range = (x2 - x1)/1.8
#                 x1 = x2 - range
#                 y1 = y2 - range
#             else:
#                 x1, y1, x2, y2 = coordinates[1], coordinates[0], coordinates[3], coordinates[2]
#             rect = plt.Rectangle((min(x1, x2), min(y1, y2)), abs(x2 - x1), abs(y2 - y1),
#                                  linewidth=1, edgecolor=colors[queries.index(query) % len(colors)], facecolor='none')
#             ax.add_patch(rect)
#         # if i != 4:
#         #     ax.set_xlim(0, 306)
#         #     ax.set_ylim(0, 306)
#         # if i == 1 or i == 5:
#         #     ax.set_xlim(0, 306)
#         #     ax.set_ylim(0, 306)
#         # if i == 2:
#         #     ax.set_xlim(0, 200)
#         #     ax.set_ylim(0, 306)
#         # if i == 3:
#         #     ax.set_xlim(0, 306)
#         #     ax.set_ylim(0, 256)
#         # if i == 4:
#         #     ax.set_xlim(0, 256)
#         #     ax.set_ylim(0, 256)

#         ax.set_xticks([])
#         ax.set_yticks([])
#         ax.set_aspect('equal', adjustable='box')
#         ax.autoscale_view()
#         ax.set_title("QW"+str(i), fontdict={'fontsize': 16})
#         i += 1

#     # Optional: Set legend on the first axis if needed
#     # handles, labels = axes[0].get_legend_handles_labels()
#     # fig.legend(handles, labels, loc='upper left', bbox_to_anchor=(1.05, 1))

#     plt.savefig('../figs/exp3/nyc_query.pdf',format='pdf',bbox_inches = 'tight') 

#     plt.show()

# # Example usage
# # json_file = '../figs/nyc_query.json'  # Update path as necessary
# # data = read_json(json_file)
# # plot_rectangles(data)

# %%
import numpy as np


labels = ['LBMC', 'CC', 'ZC', 'HC', 'QUILTS']

all_methods = [[883.32, 883.32, 883.32, 883.32, 785, 783],
 [995, 995, 995, 995, 995, 995],
 [991, 991, 991, 991, 991, 991], 
 [990, 990, 990, 990, 990, 990], 
 [983, 983, 983, 983, 931, 931]]

x_labels = ["16", "20", "24", "28", "32", "64"]

width = 0.14
# bar_alpha = 1.0
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(x_labels))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]
r4 = [x + width for x in r3]
r5 = [x + width for x in r4]
rs = [r1, r2, r3, r4, r5]

fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

colors = ['silver','red', 'cornflowerblue', 'orange','orchid','limegreen','brown']

x = np.array([0,1,2,3,4])
x = np.array([0,1,2,3,4,5])

for i in range(len(all_methods)):
    # plt.plot(x, all_methods[i], label=labels[i], linewidth=linewidth, color=colors[i], marker=markers[i], markersize=markersize)
    rects1 = ax.bar(rs[i], all_methods[i], width, hatch=patterns[i],label=labels[i], color=colors[i])

# ax.set_yscale('log')
ax.set_xlabel('$\ell$', fontsize=label_fontsize)
ax.set_ylabel('Size (MB)', fontsize=label_fontsize)

plt.xticks(x, x_labels)



ax.set_xticks([r + int(len(rs) / 2)*width for r in range(len(all_methods[0]))])
ax.set_xticklabels(x_labels, fontsize=tick_fontsize)

y_labels = [0, 200, 400, 600, 800, 1000, 1200, 1400]
ax.set_yticks(y_labels)

ax.legend(ncol=3, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, frameon=False)

# Adjust the layout to make room for the legend
plt.tight_layout()

plt.savefig('../figs/exp3/hudi_tpc_vary_bits_TPCH.pdf',format='pdf',bbox_inches = 'tight') 



plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np


labels = ['LBMC', 'CC', 'ZC', 'HC', 'QUILTS']

all_methods = [[5660, 5734, 5794, 5863, 4910, 4910],
 [7449, 7449, 7449, 7449, 7449, 7449],
 [11737, 11737, 11737, 11737, 11737, 11737], 
 [11090, 11090, 11090, 11090, 11090, 11090], 
 [8883, 8449, 7737, 7090, 6991, 6991]]

all_methods = [[item / 1000 for item in all_method] for all_method in all_methods]

x_labels = ["16", "20", "24", "28", "32", "64"]

width = 0.14
# bar_alpha = 1.0
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(x_labels))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]
r4 = [x + width for x in r3]
r5 = [x + width for x in r4]
rs = [r1, r2, r3, r4, r5]

fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

colors = ['silver','red', 'cornflowerblue', 'orange','orchid','limegreen','brown']

x = np.array([0,1,2,3,4])
x = np.array([0,1,2,3,4,5])

for i in range(len(all_methods)):
    # plt.plot(x, all_methods[i], label=labels[i], linewidth=linewidth, color=colors[i], marker=markers[i], markersize=markersize)
    rects1 = ax.bar(rs[i], all_methods[i], width, hatch=patterns[i],label=labels[i], color=colors[i])

# ax.set_yscale('log')
ax.set_xlabel('$\ell$', fontsize=label_fontsize)
ax.set_ylabel('Time (s)', fontsize=label_fontsize)

plt.xticks(x, x_labels)



ax.set_xticks([r + int(len(rs) / 2)*width for r in range(len(all_methods[0]))])
ax.set_xticklabels(x_labels, fontsize=tick_fontsize)

y_labels = [0, 4, 8, 12, 16]
ax.set_yticks(y_labels)

ax.legend(ncol=3, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, frameon=False)

# Adjust the layout to make room for the legend
plt.tight_layout()

plt.savefig('../figs/exp3/hudi_tpc_vary_bits_TPCH_CPU.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
x_labels = ["16", "20", "24", "28", "32"]

colors = ['red', 'orange','orchid','limegreen', 'cornflowerblue', 'silver','brown']
markers=['o','^','s','1','x','2']

labels = ['LBMC', 'CC', 'ZC', 'HC', 'BMTree', 'QUILTS']

all_methods = [[1062, 1068, 1044, 1044, 1044], 
 [4330, 4319, 4319, 4319, 4319], 
 [3485, 3466, 3466, 3466, 3466], 
 [3987, 3959, 3960, 3960, 3960], 
 [1565,1489,1489,1489,1489],
 [1106, 1161, 1161, 1147, 1257]]

fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

x = np.array([0,1,2,3,4])

for i in range(len(all_methods)):
    plt.plot(x, all_methods[i], label=labels[i], linewidth=linewidth, color=colors[i], marker=markers[i], markersize=markersize)

ax.set_yscale('log')
ax.set_xlabel('$\ell$', fontsize=label_fontsize)
ax.set_ylabel('# Block accesses', fontsize=label_fontsize)

plt.xticks(x, x_labels)

ax.set_xticklabels(x_labels, fontsize=tick_fontsize)

y_labels = [1000, 10000, 20000]
ax.set_yticks(y_labels)

ax.legend(loc='upper center', ncol=3, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, framealpha=0)

# Adjust the layout to make room for the legend
plt.tight_layout()


plt.savefig('../figs/exp2/PG_tpc_vary_bits_OSM.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np


# BMTree_SP = [1011, 1186, 1279, 1380, 1441]  # build cost
# LBMC = [5, 6, 6, 6, 7]

x_labels = ["16", "20", "24", "28", "32"]

labels = ['LBMC','BMTree', 'QUILTS']

all_methods = [[5, 6, 6, 6, 7], 
 [1115, 1189, 1254, 1368, 1433],
[157, 284, 413, 634, 1142]]

# Define color and font size variables
color_A = 'blue'
color_B = 'orange'
# bar_alpha = 1.0


# Set up figure and axes
fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Width of the bars

# Create an array with the position of each bar along the x-axis
# r1 = np.arange(len(x_labels))
# r2 = [x + width for x in r1]
# r3 = [x + width for x in r2]
# r4 = [x + width for x in r3]
# r5 = [x + width for x in r4]
# rs = [r1, r2, r3, r4, r5]

x = np.array([0,1,2,3,4])

# for i in range(len(all_methods)):
#     plt.plot(x, all_methods[i], label=labels[i], linewidth=linewidth, color=colors[i], marker=markers[i], markersize=markersize)

plt.plot(x, all_methods[0], label=labels[0], linewidth=linewidth, color=colors[0], marker=markers[0], markersize=markersize)
plt.plot(x, all_methods[1], label=labels[1], linewidth=linewidth, color=colors[4], marker=markers[4], markersize=markersize)
plt.plot(x, all_methods[2], label=labels[2], linewidth=linewidth, color=colors[5], marker=markers[5], markersize=markersize)

# ax.set_yscale('log')
ax.set_xlabel('$\ell$', fontsize=label_fontsize)
ax.set_ylabel('Time (s)', fontsize=label_fontsize)
# ax.set_title('Time Saved Comparison of Methods A and B', fontsize=tick_fontsize)
# ax.set_xticks([r + int(len(rs) / 2)*width for r in range(len(all_methods[0]))])

plt.xticks(x, x_labels)

ax.set_xticklabels(x_labels, fontsize=tick_fontsize)

y_labels = [10, 1000, 2000]
ax.set_yticks(y_labels)

ax.legend(ncol=2, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, frameon=False)

# Adjust the layout to make room for the legend
plt.tight_layout()

plt.savefig('../figs/exp2/PG_tpc_vary_bits_OSM_time.pdf',format='pdf',bbox_inches = 'tight') 
plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np


labels = ['LBMC', 'CC', 'ZC', 'HC', 'QUILTS']


all_methods = [[783, 783, 782, 783, 796],
 [995, 987, 987, 986, 992],
 [991, 1039, 1039, 1038, 1038], 
 [990, 1037, 1037, 1037, 1037], 
 [931, 927, 928, 927, 934]]

x_labels = ["2", "3", "4", "5", "6"]

width = 0.14
bar_alpha = 1.0
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(x_labels))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]
r4 = [x + width for x in r3]
r5 = [x + width for x in r4]
rs = [r1, r2, r3, r4, r5]

fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

colors = ['silver','red', 'cornflowerblue', 'orange','orchid','limegreen','brown']

x = np.array([0,1,2,3,4])

for i in range(len(all_methods)):
    # plt.plot(x, all_methods[i], label=labels[i], linewidth=linewidth, color=colors[i], marker=markers[i], markersize=markersize)
    rects1 = ax.bar(rs[i], all_methods[i], width, hatch=patterns[i],label=labels[i], color=colors[i])

# ax.set_yscale('log')
ax.set_xlabel('$d$', fontsize=label_fontsize)
ax.set_ylabel('Size (MB)', fontsize=label_fontsize)

plt.xticks(x, x_labels)



ax.set_xticks([r + int(len(rs) / 2)*width for r in range(len(all_methods[0]))])
ax.set_xticklabels(x_labels, fontsize=tick_fontsize)

y_labels = [0, 200, 400, 600, 800, 1000, 1200, 1400, 1600]
ax.set_yticks(y_labels)

ax.legend(ncol=3, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, frameon=False)

# Adjust the layout to make room for the legend
plt.tight_layout()

plt.savefig('../figs/exp3/hudi_tpc_vary_dim_TPCH.pdf',format='pdf',bbox_inches = 'tight') 



plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
import numpy as np

labels = ['LBMC', 'CC', 'ZC', 'HC', 'QUILTS']

all_methods = [[4990, 5442, 5576, 5708, 5973],
 [7449, 8873, 8975, 9187, 9342],
 [11737, 11849, 12025, 12642, 12866], 
 [11090, 11701, 11987, 12474, 12697], 
 [6991, 7442, 8576, 8708, 8801]]

all_methods = [[item / 1000 for item in all_method] for all_method in all_methods]

x_labels = ["2", "3", "4", "5", "6"]

width = 0.14
bar_alpha = 1.0
# Create an array with the position of each bar along the x-axis
r1 = np.arange(len(x_labels))
r2 = [x + width for x in r1]
r3 = [x + width for x in r2]
r4 = [x + width for x in r3]
r5 = [x + width for x in r4]
rs = [r1, r2, r3, r4, r5]

fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

colors = ['silver','red', 'cornflowerblue', 'orange','orchid','limegreen','brown']

x = np.array([0,1,2,3,4])

for i in range(len(all_methods)):
    # plt.plot(x, all_methods[i], label=labels[i], linewidth=linewidth, color=colors[i], marker=markers[i], markersize=markersize)
    rects1 = ax.bar(rs[i], all_methods[i], width, hatch=patterns[i],label=labels[i], color=colors[i])

# ax.set_yscale('log')
ax.set_xlabel('$d$', fontsize=label_fontsize)
ax.set_ylabel('Time (s)', fontsize=label_fontsize)

plt.xticks(x, x_labels)

ax.set_xticks([r + int(len(rs) / 2)*width for r in range(len(all_methods[0]))])
ax.set_xticklabels(x_labels, fontsize=tick_fontsize)

y_labels = [0, 4, 8, 12, 16]
ax.set_yticks(y_labels)

ax.legend(ncol=3, labelspacing=0.0, columnspacing=1, borderpad=0, handlelength=1, fontsize=tick_fontsize, fancybox=True, frameon=False)

# Adjust the layout to make room for the legend
plt.tight_layout()


plt.savefig('../figs/exp3/hudi_tpc_vary_dim_TPCH_CPU.pdf',format='pdf',bbox_inches = 'tight') 

plt.show()
# Out:
# 'created' timestamp seems very low; regarding as unix timestamp
# 'modified' timestamp seems very low; regarding as unix timestamp

# %%
# import numpy as np
# from scipy.spatial import distance_matrix
# from scipy.sparse import csgraph
# from scipy.linalg import eigh
# from hilbertcurve.hilbertcurve import HilbertCurve
# from time import time
# import pandas as pd
# import bisect

# # Function to sort points using Z-order curve (Morton order)
# def z_order_sort(points):
#     scaled_points = (points * 1024).astype(int)
#     def compute_morton(x, y):
#         answer = 0
#         x, y = int(x), int(y)
#         bits = max(x.bit_length(), y.bit_length())
#         for i in range(bits):
#             answer |= ((x >> i) & 1) << (2 * i)
#             answer |= ((y >> i) & 1) << (2 * i + 1)
#         return answer
#     morton_codes = [compute_morton(x, y) for x, y in scaled_points]
#     # # Append the morton_codes as a new column to the points
#     # points = np.hstack((points, morton_codes.reshape(-1, 1)))
#     sorted_indices = np.argsort(morton_codes)
#     morton_codes.sort()
#     return points[sorted_indices], morton_codes

# def z_order_sort_(points):
#     scaled_points = (points * 1024).astype(int)
#     def compute_morton(x, y):
#         answer = 0
#         x, y = int(x), int(y)
#         bits = max(x.bit_length(), y.bit_length())
#         for i in range(bits):
#             answer |= ((x >> i) & 1) << (2 * i)
#             answer |= ((y >> i) & 1) << (2 * i + 1)
#         return answer
#     morton_codes = [compute_morton(x, y) for x, y in scaled_points]
#     return morton_codes

# # Function to sort points using Hilbert curve
# def hilbert_sort(points, order=8):
#     p = 2
#     hilbert_curve = HilbertCurve(order, p)
#     max_h = 2**order
#     scaled_points = (points * max_h).astype(int)
#     hilbert_distances = [hilbert_curve.distance_from_point(coords) for coords in scaled_points]
#     sorted_indices = np.argsort(hilbert_distances)
#     hilbert_distances.sort()
#     return points[sorted_indices], hilbert_distances

# def hilbert_sort_(points, order=8):
#     p = 2
#     hilbert_curve = HilbertCurve(order, p)
#     max_h = 2**order
#     scaled_points = (points * max_h).astype(int)
#     hilbert_distances = [hilbert_curve.distance_from_point(coords) for coords in scaled_points]
#     return hilbert_distances

# def LBMC_sort(points, bits_str="XYXYXYXYXYXYXYXY", order=8):
#     grid_size = 2**order
#     print(bits_str[::-1])
#     bits=[[i for i, x in enumerate(bits_str) if x == 'X'],[i for i, x in enumerate(bits_str) if x == 'Y']]
#     scaled_points = (points * grid_size).astype(int)

#     def get_z_value(x, bits_order=[[1,3,5,7],[0,2,4,6]]):
#         res = 0
#         x_len = len(x)
#         bits = len(bits_order[0])
#         for i in range(bits):
#             for j in range(x_len):
#                 res+= int(x[j] % 2) * 1 << (bits_order[j][i])
#                 x[j] /= 2
#         return res

#     morton_codes = [get_z_value([x, y], bits) for x, y in scaled_points]
#     sorted_indices = np.argsort(morton_codes)
#     morton_codes.sort()
#     return points[sorted_indices], morton_codes

# def LBMC_sort_(points, bits_str="XYXYXYXYXYXYXYXY", order=8):
#     grid_size = 2**order
#     print(bits_str[::-1])
#     bits=[[i for i, x in enumerate(bits_str) if x == 'X'],[i for i, x in enumerate(bits_str) if x == 'Y']]
#     scaled_points = (points * grid_size).astype(int)

#     def get_z_value(x, bits_order=[[1,3,5,7],[0,2,4,6]]):
#         res = 0
#         x_len = len(x)
#         bits = len(bits_order[0])
#         for i in range(bits):
#             for j in range(x_len):
#                 res+= int(x[j] % 2) * 1 << (bits_order[j][i])
#                 x[j] /= 2
#         return res

#     morton_codes = [get_z_value([x, y], bits) for x, y in scaled_points]
#     return morton_codes

# def range_query(queries, lower_sfcs, upper_sfcs, points, sfcs):
#     result = []
#     if lower_sfcs:
#         for i in range(len(queries)):
#             lower = lower_sfcs[i]
#             upper = upper_sfcs[i]
#             left = bisect.bisect_left(sfcs, lower)
#             right = bisect.bisect_right(sfcs, upper)
#             query = queries[i]
#             for point in points[left:right]:
#                 if point[0] < query[0][0] or point[0] > query[0][1] or point[1] < query[1][0] or point[1] > query[1][1]:
#                     continue
#                 result.append(point)
#     else:
#         for query in queries:
#             for point in points:
#                 if point[0] < query[0][0] or point[0] > query[0][1] or point[1] < query[1][0] or point[1] > query[1][1]:
#                     continue
#                 result.append(point)
#     return result

# def compare_orderings(n=1000):

#     # Generate some random 2D spatial data points
#     np.random.seed(0)
#     coords = np.random.rand(n, 2)

#     # Generate random queries
#     queries = []
#     lower_querys = []
#     upper_querys = []
#     num_queries = 10000
#     for _ in range(num_queries):
#         x_min = np.random.uniform(0, 1)
#         y_min = np.random.uniform(0, 1)
#         x_max = np.random.uniform(x_min, 1)
#         y_max = np.random.uniform(y_min, 1)
#         queries.append([[x_min, x_max], [y_min, y_max]])
#         lower_querys.append([x_min, y_min])
#         upper_querys.append([x_max, y_max])

#     df = pd.DataFrame(queries)
#     df.to_csv('queries.csv', index=False, header=False)
    
#     # Spectral sorting using the similarity matrix and Laplacian
#     start_time = time()
#     dist_matrix = distance_matrix(coords, coords)
#     sigma = np.std(dist_matrix)
#     similarity_matrix = np.exp(-dist_matrix ** 2 / (2 * sigma ** 2))
#     laplacian = csgraph.laplacian(similarity_matrix, normed=True)
#     eigenvalues, eigenvectors = eigh(laplacian)
#     sorted_indices = np.argsort(eigenvectors[:, 1])
#     sorted_coords = coords[sorted_indices]
#     spectral_time = time() - start_time

#     start_time = time()
#     result = range_query(queries, None, None, sorted_coords.tolist(), eigenvalues)
#     spectral_query_time = time() - start_time

#     df = pd.DataFrame(sorted_coords)
#     df.to_csv(f'spectral_{n}.csv', index=False, header=False)
    
#     # Time the Z-curve sorting
#     start_time = time()
#     z_sorted_coords, z_sorted_sfcs = z_order_sort(coords)
#     z_time = time() - start_time

#     lower_sfcs = z_order_sort_(np.array(lower_querys))
#     upper_sfcs = z_order_sort_(np.array(upper_querys))
#     start_time = time()
#     result = range_query(queries, lower_sfcs, upper_sfcs, z_sorted_coords.tolist(), z_sorted_sfcs)
#     z_query_time = time() - start_time
    
#     # Time the Hilbert curve sorting
#     start_time = time()
#     hilbert_sorted_coords, hilbert_sorted_sfcs = hilbert_sort(coords)
#     hilbert_time = time() - start_time    

#     lower_sfcs = hilbert_sort_(np.array(lower_querys))
#     upper_sfcs = hilbert_sort_(np.array(upper_querys))
#     start_time = time()
#     result = range_query(queries, lower_sfcs, upper_sfcs, hilbert_sorted_coords.tolist(), hilbert_sorted_sfcs)
#     hilbert_query_time = time() - start_time

#     # Time the LBMC sorting
#     start_time = time()
#     lbmc_sorted_coords, lbmc_sorted_sfcs = LBMC_sort(coords, bits_str="XYXYYXYXYXXYYXYX")
#     lbmc_time = time() - start_time

#     lower_sfcs = LBMC_sort_(np.array(lower_querys))
#     upper_sfcs = LBMC_sort_(np.array(upper_querys))
#     start_time = time()
#     result = range_query(queries, lower_sfcs, upper_sfcs, lbmc_sorted_coords.tolist(), lbmc_sorted_sfcs)
#     lbmc_query_time = time() - start_time

#     # Time the LBMC sorting
#     start_time = time()
#     linear_sorted_coords, linear_sorted_sfcs = LBMC_sort(coords, bits_str="XXXXXXXXYYYYYYYY")
#     linear_time = time() - start_time

#     lower_sfcs = LBMC_sort_(np.array(lower_querys))
#     upper_sfcs = LBMC_sort_(np.array(upper_querys))
#     start_time = time()
#     result = range_query(queries, lower_sfcs, upper_sfcs, linear_sorted_coords.tolist(), linear_sorted_sfcs)
#     linear_query_time = time() - start_time
    
#     # Output times in seconds, rounded to four decimal places
#     spectral_time, z_time, hilbert_time, lbmc_time, linear_time = map(lambda t: round(t, 4), [spectral_time, z_time, hilbert_time, lbmc_time, linear_time])
#     spectral_query_time, z_query_time, hilbert_query_time, lbmc_query_time, linear_query_time = map(lambda t: round(t, 4), [spectral_query_time, z_query_time, hilbert_query_time, lbmc_query_time, linear_query_time])
    
#     print("Time cost: ", spectral_time, z_time, hilbert_time, lbmc_time, linear_time)
#     print("Query Time cost: ", spectral_query_time, z_query_time, hilbert_query_time, lbmc_query_time, linear_query_time)
    
#     # Plotting the points
#     plt.figure(figsize=(20, 4))
    
#     # Original Data Points
#     ax = plt.subplot(1, 6, 1)
#     plt.scatter(coords[:, 0], coords[:, 1], s=10, color='blue')
#     plt.title('Original Data Points')
#     ax.set_xticks([])  # Hide x-axis ticks
#     ax.set_yticks([])  # Hide y-axis ticks
    
#     # Spectrally Ordered Data Points
#     ax = plt.subplot(1, 6, 2)
#     plt.scatter(sorted_coords[:, 0], sorted_coords[:, 1], s=10, color='blue', zorder=2)
#     plt.plot(sorted_coords[:, 0], sorted_coords[:, 1], color='gray', zorder=1)
#     plt.title('Spectral Ordering')
#     ax.set_xticks([])  # Hide x-axis ticks
#     ax.set_yticks([])  # Hide y-axis ticks

#     # LBMC Ordered Points
#     ax = plt.subplot(1, 6, 3)
#     plt.scatter(lbmc_sorted_coords[:, 0], lbmc_sorted_coords[:, 1], s=10, color='blue', zorder=2)
#     plt.plot(lbmc_sorted_coords[:, 0], lbmc_sorted_coords[:, 1], color='gray', zorder=1)
#     plt.title('LBMC')
#     ax.set_xticks([])  # Hide x-axis ticks
#     ax.set_yticks([])  # Hide y-axis ticks
    
#     # Z-curve Ordered Points
#     ax = plt.subplot(1, 6, 4)
#     plt.scatter(z_sorted_coords[:, 0], z_sorted_coords[:, 1], s=10, color='blue', zorder=2)
#     plt.plot(z_sorted_coords[:, 0], z_sorted_coords[:, 1], color='gray', zorder=1)
#     plt.title('Z-Curve')
#     ax.set_xticks([])  # Hide x-axis ticks
#     ax.set_yticks([])  # Hide y-axis ticks
    
#     # Hilbert Curve Ordered Points
#     ax = plt.subplot(1, 6, 5)
#     plt.scatter(hilbert_sorted_coords[:, 0], hilbert_sorted_coords[:, 1], s=10, color='blue', zorder=2)
#     plt.plot(hilbert_sorted_coords[:, 0], hilbert_sorted_coords[:, 1], color='gray', zorder=1)
#     plt.title('Hilbert Curve')
#     ax.set_xticks([])  # Hide x-axis ticks
#     ax.set_yticks([])  # Hide y-axis ticks

#     # Linear Ordered Points
#     ax = plt.subplot(1, 6, 6)
#     plt.scatter(linear_sorted_coords[:, 0], linear_sorted_coords[:, 1], s=10, color='blue', zorder=2)
#     plt.plot(linear_sorted_coords[:, 0], linear_sorted_coords[:, 1], color='gray', zorder=1)
#     plt.title('Linear Ordering')
#     ax.set_xticks([])  # Hide x-axis ticks
#     ax.set_yticks([])  # Hide y-axis ticks

#     plt.savefig('../figs/compare_orderings_' + str(n) + '.pdf',format='pdf',bbox_inches = 'tight') 

#     plt.tight_layout()
#     plt.show()

# # compare_orderings(n=10)
# # compare_orderings( n=100)
# # compare_orderings(n=1000)
# # compare_orderings(n=10000)
# # compare_orderings(n=100000)

# %%
# n_values = [10, 100, 1000, 10000]
# spectral_times = [0.0006, 0.0147, 0.3099, 88.1142]
# zc_times = [0.0002, 0.0004, 0.0018, 0.0273]
# hc_times = [0.0002, 0.0009, 0.0042, 0.1198]
# lbmc_time = [0.2002, 0.2009, 0.2042, 0.3198]
# linear_time = [0.0001, 0.0003, 0.0012, 0.0153]


# fig, ax = plt.subplots(figsize=(12, 6))

# ax.plot(n_values, spectral_times, label='Spectral Ordering', marker='o', linewidth=2, markersize=8)
# ax.plot(n_values, zc_times, label='ZC', marker='s', linewidth=2, markersize=8)
# ax.plot(n_values, hc_times, label='HC', marker='^', linewidth=2, markersize=8)
# ax.plot(n_values, lbmc_time, label='LBMC', marker='^', linewidth=2, markersize=8)
# ax.plot(n_values, linear_time, label='CC', marker='^', linewidth=2, markersize=8)

# ax.set_ylim(0.00005, 1000)

# ax.set_xlabel('Number of Points (n)', fontsize=24)
# ax.set_ylabel('Time Cost (s)', fontsize=24)
# # ax.set_title('Time Cost Comparison of Spectral, ZC, and HC Algorithms')
# ax.set_xscale('log')
# ax.set_yscale('log')
# ax.set_xticks(n_values)
# ax.get_xaxis().set_major_formatter(plt.ScalarFormatter())
# ax.tick_params(axis='both', which='major', labelsize=24)  # Adjust tick labels

# ax.legend(frameon=False, fontsize=20)

# plt.savefig('../figs/compare_orderings_time.pdf',format='pdf',bbox_inches = 'tight') 

# plt.show()

# %%
# n_values = [10, 100, 1000, 10000]
# spectral_times = [0.0034, 0.0839, 0.4239, 2.7188]
# zc_times = [0.0038, 0.0139, 0.0988, 0.9792]
# hc_times = [0.004, 0.0147, 0.1054, 0.9865]
# lbmc_time = [0.0035, 0.0137, 0.0996, 0.9662]
# linear_time = [0.0033, 0.0249, 0.1409, 1.3029]


# fig, ax = plt.subplots(figsize=(12, 6))

# ax.plot(n_values, spectral_times, label='Spectral Ordering', marker='o', linewidth=2, markersize=8)
# ax.plot(n_values, zc_times, label='ZC', marker='s', linewidth=2, markersize=8)
# ax.plot(n_values, hc_times, label='HC', marker='^', linewidth=2, markersize=8)
# ax.plot(n_values, lbmc_time, label='LBMC', marker='^', linewidth=2, markersize=8)
# ax.plot(n_values, linear_time, label='CC', marker='^', linewidth=2, markersize=8)

# ax.set_ylim(0.001, 10)

# ax.set_xlabel('Number of Points (n)', fontsize=24)
# ax.set_ylabel('Query Time (s)', fontsize=24)
# # ax.set_title('Time Cost Comparison of Spectral, ZC, and HC Algorithms')
# ax.set_xscale('log')
# ax.set_yscale('log')
# ax.set_xticks(n_values)
# ax.get_xaxis().set_major_formatter(plt.ScalarFormatter())
# ax.tick_params(axis='both', which='major', labelsize=24)  # Adjust tick labels

# ax.legend(frameon=False, fontsize=20)

# plt.savefig('../figs/compare_query_cost.pdf',format='pdf',bbox_inches = 'tight') 

# plt.show()
